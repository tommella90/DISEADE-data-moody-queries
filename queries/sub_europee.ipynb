# %% [markdown]
# # CONVERT FILES WITH DUCK_DB

# %%
import pandas as pd
import duckdb
import os
import time
import numpy as np
from utils import time, data_processor, constants

# %%
OUTPUT_PATH = r"..\data_processed\\guo_subs_europee\\subs_eu\\" 

eu27_countries = constants.eu

# %% [markdown]
# ## Ownership history

# %%
TEMP_TABLE_FIRMOGRAPHICS = "..\\data_processed\\firmographics_processed\\*.parquet" 
TEMP_TABLE_KEY_FINANCIALS = "..\\data_processed\\firmographics_historicals_processed"


def get_ownership_data(year, country, path=None):
    print(f"{country} - {year}...")
    COUNTRY_KEY_FINANCIALS = TEMP_TABLE_KEY_FINANCIALS + f"\\firmographics_historicals_{country}.parquet"
            
            
    query = f"""
        SELECT
            main.subsidiary_bvd_id,
            main.guo_25,
            firmographics_sub.nuts2 AS subsidiary_nuts2,
            firmographics_sub.nace_rev_2_core_code_4_digits_ AS subsidiary_nace4,
            firmographics_guo.nuts2 AS guo_nuts2,
            firmographics_guo.nace_rev_2_core_code_4_digits_ AS guo_nace4,
            firmographics_guo.type_of_entity AS guo_type_of_entity,
            firmographics_guo.status AS guo_status,
            {year} AS year,
            key_financials.number_of_employees AS guo_number_of_employees,
            key_financials.closing_date AS guo_closing_date
        FROM 
            '{path}' AS main
        LEFT JOIN 
            '{TEMP_TABLE_FIRMOGRAPHICS}' AS firmographics_sub
        ON 
            main.subsidiary_bvd_id = firmographics_sub.bvd_id_number
        LEFT JOIN
            '{TEMP_TABLE_FIRMOGRAPHICS}' AS firmographics_guo
        ON
            main.guo_25 = firmographics_guo.bvd_id_number
        LEFT JOIN 
            (SELECT * 
             FROM '{COUNTRY_KEY_FINANCIALS}'
             WHERE 
                year = {year}
            ) AS key_financials
        ON
            main.subsidiary_bvd_id = key_financials.bvd_id_number   -- CHANGE HERE FOR SUBS
        AND
            key_financials.year = {year}

        WHERE 
            main."type_of_relation" = 'GUO 25'
        AND 
            main."subsidiary_bvd_id" LIKE '{country}%'
    """

    conn = duckdb.connect()
    df = conn.execute(query).fetchdf()
    return df

# %%
@time.time_it
def fetch_and_convert_to_excel(year, country, path, output_path):
    df = get_ownership_data(year, country, path)
    os.makedirs(output_path, exist_ok=True)
    slices = data_processor.split_in_chunks(df, 5)

    for i, s in enumerate(slices):
        s.to_csv(f"{output_path}\\{country}_{year}_chunk_{i+1}.csv", index=False)
        print(f"Data for {country} - {year} - slice_{i+1} has been converted.")

# %% [markdown]
# ### Test

# %%
# path = "..\\data_raw\\ownership_history\\links_2007\\*.parquet"
country = "DE"
year = "2009"
path = "..\\data_raw\\ownership_history\\links_2007\\*.parquet"

df = get_ownership_data(
    path=path,
    year=year,
    country=country,
)
# fetch_and_convert_to_excel(country=country, year=year, path=path, output_path=output_path)
# Out:
# DE - 2009...

# %% [markdown]
# ## Query data

# %%
import time
import json

errors = {}

total_start = time.time()
start_time = time.time()


for country in eu27_countries:
    for year in range(2022, 2023):
        year = str(year)
        try:
            path = f"..\\data_raw\\ownership_history\\links_{year}\\*.parquet"
            fetch_and_convert_to_excel(year, country, path, OUTPUT_PATH)  
            end_time = time.time()
            duration = end_time - start_time
            print(f"Data for {country} - {year} has been converted to Stata in {duration:.2f} seconds.")
        except Exception as e:
            errors[f"{country} - {year}"] = str(e)
            print(f"Error {country} - {year}")
            continue


end_time = time.time()
duration = end_time - start_time
total_end = time.time()
total_duration = total_end - total_start
print(f"Total execution time: {total_duration:.2f} seconds.")

with open("errors_guos.json", "w") as f:
    json.dump(errors, f)
# Out:
# AT - 2022...
# Data for AT - 2022 - slice_1 has been converted.
# Data for AT - 2022 - slice_2 has been converted.
# Data for AT - 2022 - slice_3 has been converted.
# Data for AT - 2022 - slice_4 has been converted.
# Data for AT - 2022 - slice_5 has been converted.
# Execution time: 95.8373 seconds
# Data for AT - 2022 has been converted to Stata in 95.84 seconds.
# BE - 2022...
# Data for BE - 2022 - slice_1 has been converted.
# Data for BE - 2022 - slice_2 has been converted.
# Data for BE - 2022 - slice_3 has been converted.
# Data for BE - 2022 - slice_4 has been converted.
# Data for BE - 2022 - slice_5 has been converted.
# Execution time: 396.7448 seconds
# Data for BE - 2022 has been converted to Stata in 492.58 seconds.
# BG - 2022...
# Data for BG - 2022 - slice_1 has been converted.
# Data for BG - 2022 - slice_2 has been converted.
# Data for BG - 2022 - slice_3 has been converted.
# Data for BG - 2022 - slice_4 has been converted.
# Data for BG - 2022 - slice_5 has been converted.
# Execution time: 151.8585 seconds
# Data for BG - 2022 has been converted to Stata in 644.44 seconds.
# HR - 2022...
# Data for HR - 2022 - slice_1 has been converted.
# Data for HR - 2022 - slice_2 has been converted.
# Data for HR - 2022 - slice_3 has been converted.
# Data for HR - 2022 - slice_4 has been converted.
# Data for HR - 2022 - slice_5 has been converted.
# Execution time: 33.2647 seconds
# Data for HR - 2022 has been converted to Stata in 677.71 seconds.
# CY - 2022...
# Data for CY - 2022 - slice_1 has been converted.
# Data for CY - 2022 - slice_2 has been converted.
# Data for CY - 2022 - slice_3 has been converted.
# Data for CY - 2022 - slice_4 has been converted.
# Data for CY - 2022 - slice_5 has been converted.
# Execution time: 29.9020 seconds
# Data for CY - 2022 has been converted to Stata in 707.61 seconds.
# CZ - 2022...
# Data for CZ - 2022 - slice_1 has been converted.
# Data for CZ - 2022 - slice_2 has been converted.
# Data for CZ - 2022 - slice_3 has been converted.
# Data for CZ - 2022 - slice_4 has been converted.
# Data for CZ - 2022 - slice_5 has been converted.
# Execution time: 321.4454 seconds
# Data for CZ - 2022 has been converted to Stata in 1029.06 seconds.
# DK - 2022...
# Data for DK - 2022 - slice_1 has been converted.
# Data for DK - 2022 - slice_2 has been converted.
# Data for DK - 2022 - slice_3 has been converted.
# Data for DK - 2022 - slice_4 has been converted.
# Data for DK - 2022 - slice_5 has been converted.
# Execution time: 140.0294 seconds
# Data for DK - 2022 has been converted to Stata in 1169.09 seconds.
# EE - 2022...
# Data for EE - 2022 - slice_1 has been converted.
# Data for EE - 2022 - slice_2 has been converted.
# Data for EE - 2022 - slice_3 has been converted.
# Data for EE - 2022 - slice_4 has been converted.
# Data for EE - 2022 - slice_5 has been converted.
# Execution time: 36.9704 seconds
# Data for EE - 2022 has been converted to Stata in 1206.06 seconds.
# FI - 2022...
# Data for FI - 2022 - slice_1 has been converted.
# Data for FI - 2022 - slice_2 has been converted.
# Data for FI - 2022 - slice_3 has been converted.
# Data for FI - 2022 - slice_4 has been converted.
# Data for FI - 2022 - slice_5 has been converted.
# Execution time: 174.5338 seconds
# Data for FI - 2022 has been converted to Stata in 1380.59 seconds.
# FR - 2022...
# Data for FR - 2022 - slice_1 has been converted.
# Data for FR - 2022 - slice_2 has been converted.
# Data for FR - 2022 - slice_3 has been converted.
# Data for FR - 2022 - slice_4 has been converted.
# Data for FR - 2022 - slice_5 has been converted.
# Execution time: 450.3851 seconds
# Data for FR - 2022 has been converted to Stata in 1830.98 seconds.
# DE - 2022...
# Data for DE - 2022 - slice_1 has been converted.
# Data for DE - 2022 - slice_2 has been converted.
# Data for DE - 2022 - slice_3 has been converted.
# Data for DE - 2022 - slice_4 has been converted.
# Data for DE - 2022 - slice_5 has been converted.
# Execution time: 328.4914 seconds
# Data for DE - 2022 has been converted to Stata in 2159.47 seconds.
# GR - 2022...
# Data for GR - 2022 - slice_1 has been converted.
# Data for GR - 2022 - slice_2 has been converted.
# Data for GR - 2022 - slice_3 has been converted.
# Data for GR - 2022 - slice_4 has been converted.
# Data for GR - 2022 - slice_5 has been converted.
# Execution time: 30.3901 seconds
# Data for GR - 2022 has been converted to Stata in 2189.86 seconds.
# HU - 2022...
# Data for HU - 2022 - slice_1 has been converted.
# Data for HU - 2022 - slice_2 has been converted.
# Data for HU - 2022 - slice_3 has been converted.
# Data for HU - 2022 - slice_4 has been converted.
# Data for HU - 2022 - slice_5 has been converted.
# Execution time: 367.5284 seconds
# Data for HU - 2022 has been converted to Stata in 2557.39 seconds.
# IE - 2022...
# Data for IE - 2022 - slice_1 has been converted.
# Data for IE - 2022 - slice_2 has been converted.
# Data for IE - 2022 - slice_3 has been converted.
# Data for IE - 2022 - slice_4 has been converted.
# Data for IE - 2022 - slice_5 has been converted.
# Execution time: 39.2337 seconds
# Data for IE - 2022 has been converted to Stata in 2596.62 seconds.
# IT - 2022...
# Data for IT - 2022 - slice_1 has been converted.
# Data for IT - 2022 - slice_2 has been converted.
# Data for IT - 2022 - slice_3 has been converted.
# Data for IT - 2022 - slice_4 has been converted.
# Data for IT - 2022 - slice_5 has been converted.
# Execution time: 441.6007 seconds
# Data for IT - 2022 has been converted to Stata in 3038.22 seconds.
# LV - 2022...
# Data for LV - 2022 - slice_1 has been converted.
# Data for LV - 2022 - slice_2 has been converted.
# Data for LV - 2022 - slice_3 has been converted.
# Data for LV - 2022 - slice_4 has been converted.
# Data for LV - 2022 - slice_5 has been converted.
# Execution time: 35.5445 seconds
# Data for LV - 2022 has been converted to Stata in 3073.77 seconds.
# LT - 2022...
# Data for LT - 2022 - slice_1 has been converted.
# Data for LT - 2022 - slice_2 has been converted.
# Data for LT - 2022 - slice_3 has been converted.
# Data for LT - 2022 - slice_4 has been converted.
# Data for LT - 2022 - slice_5 has been converted.
# Execution time: 31.4858 seconds
# Data for LT - 2022 has been converted to Stata in 3105.25 seconds.
# LU - 2022...
# Data for LU - 2022 - slice_1 has been converted.
# Data for LU - 2022 - slice_2 has been converted.
# Data for LU - 2022 - slice_3 has been converted.
# Data for LU - 2022 - slice_4 has been converted.
# Data for LU - 2022 - slice_5 has been converted.
# Execution time: 33.8299 seconds
# Data for LU - 2022 has been converted to Stata in 3139.08 seconds.
# MT - 2022...
# Data for MT - 2022 - slice_1 has been converted.
# Data for MT - 2022 - slice_2 has been converted.
# Data for MT - 2022 - slice_3 has been converted.
# Data for MT - 2022 - slice_4 has been converted.
# Data for MT - 2022 - slice_5 has been converted.
# Execution time: 27.7853 seconds
# Data for MT - 2022 has been converted to Stata in 3166.87 seconds.
# NL - 2022...
# Data for NL - 2022 - slice_1 has been converted.
# Data for NL - 2022 - slice_2 has been converted.
# Data for NL - 2022 - slice_3 has been converted.
# Data for NL - 2022 - slice_4 has been converted.
# Data for NL - 2022 - slice_5 has been converted.
# Execution time: 480.2209 seconds
# Data for NL - 2022 has been converted to Stata in 3647.09 seconds.
# PL - 2022...
# Data for PL - 2022 - slice_1 has been converted.
# Data for PL - 2022 - slice_2 has been converted.
# Data for PL - 2022 - slice_3 has been converted.
# Data for PL - 2022 - slice_4 has been converted.
# Data for PL - 2022 - slice_5 has been converted.
# Execution time: 69.7410 seconds
# Data for PL - 2022 has been converted to Stata in 3716.83 seconds.
# PT - 2022...
# Data for PT - 2022 - slice_1 has been converted.
# Data for PT - 2022 - slice_2 has been converted.
# Data for PT - 2022 - slice_3 has been converted.
# Data for PT - 2022 - slice_4 has been converted.
# Data for PT - 2022 - slice_5 has been converted.
# Execution time: 70.2844 seconds
# Data for PT - 2022 has been converted to Stata in 3787.12 seconds.
# RO - 2022...
# Data for RO - 2022 - slice_1 has been converted.
# Data for RO - 2022 - slice_2 has been converted.
# Data for RO - 2022 - slice_3 has been converted.
# Data for RO - 2022 - slice_4 has been converted.
# Data for RO - 2022 - slice_5 has been converted.
# Execution time: 291.9895 seconds
# Data for RO - 2022 has been converted to Stata in 4079.10 seconds.
# SK - 2022...
# Data for SK - 2022 - slice_1 has been converted.
# Data for SK - 2022 - slice_2 has been converted.
# Data for SK - 2022 - slice_3 has been converted.
# Data for SK - 2022 - slice_4 has been converted.
# Data for SK - 2022 - slice_5 has been converted.
# Execution time: 63.2368 seconds
# Data for SK - 2022 has been converted to Stata in 4142.34 seconds.
# SI - 2022...
# Data for SI - 2022 - slice_1 has been converted.
# Data for SI - 2022 - slice_2 has been converted.
# Data for SI - 2022 - slice_3 has been converted.
# Data for SI - 2022 - slice_4 has been converted.
# Data for SI - 2022 - slice_5 has been converted.
# Execution time: 26.1212 seconds
# Data for SI - 2022 has been converted to Stata in 4168.46 seconds.
# ES - 2022...
# Data for ES - 2022 - slice_1 has been converted.
# Data for ES - 2022 - slice_2 has been converted.
# Data for ES - 2022 - slice_3 has been converted.
# Data for ES - 2022 - slice_4 has been converted.
# Data for ES - 2022 - slice_5 has been converted.
# Execution time: 268.4451 seconds
# Data for ES - 2022 has been converted to Stata in 4436.91 seconds.
# SE - 2022...
# Data for SE - 2022 - slice_1 has been converted.
# Data for SE - 2022 - slice_2 has been converted.
# Data for SE - 2022 - slice_3 has been converted.
# Data for SE - 2022 - slice_4 has been converted.
# Data for SE - 2022 - slice_5 has been converted.
# Execution time: 61.2376 seconds
# Data for SE - 2022 has been converted to Stata in 4498.15 seconds.
# Total execution time: 4498.15 seconds.

# %%
# open errors
import json 

with open("errors/errors_subs.json", "r") as f:
    errors = json.load(f)

errors
# Out:
# {}

# %% [markdown]
# ## Zip the files

# %%
ZIP_OUTPOUT = "..\\zipped_files\\subs_eu"

data_processor.compress_csv_files(folder_to_zip=OUTPUT_PATH, zip_output=ZIP_OUTPOUT)
# Out:
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\EE_
chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\SK_2013_chunk_5.csv to ..\zipped_files\subs_eu\SK_2013_chunk_5.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\HR_2018_chunk_2.csv to ..\zipped_files\subs_eu\HR_2018_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\SK_2016_chunk_1.csv to ..\zipped_files\subs_eu\SK_2016_chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\SK_2012_chunk_5.csv to ..\zipped_files\subs_eu\SK_2012_chunk_5.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\LT_2010_chunk_3.csv to ..\zipped_files\subs_eu\LT_2010_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\CY_2019_chunk_2.csv to ..\zipped_files\subs_eu\CY_2019_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\HR_2016_chunk_5.csv to ..\zipped_files\subs_eu\HR_2016_chunk_5.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\IE_2011_chunk_5.csv to ..\zipped_files\subs_eu\IE_2011_chunk_5.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\MT_2019_chunk_4.csv to ..\zipped_files\subs_eu\MT_2019_chunk_4.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\DK_2018_chunk_2.csv to ..\zipped_files\subs_eu\DK_2018_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\LU_2019_chunk_4.csv to ..\zipped_files\subs_eu\LU_2019_chunk_4.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\EE_2019_chunk_3.csv to ..\zipped_files\subs_eu\EE_2019_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\SE_2013_chunk_3.csv to ..\zipped_files\subs_eu\SE_2013_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\MK_2014_chunk_4.csv to ..\zipped_files\subs_eu\MK_2014_chunk_4.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\GR_2015_chunk_3.csv to ..\zipped_files\subs_eu\GR_2015_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\LV_2021_chunk_3.csv to ..\zipped_files\subs_eu\LV_2021_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\SE_2019_chunk_1.csv to ..\zipped_files\subs_eu\SE_2019_chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\LU_2012_chunk_5.csv to ..\zipped_files\subs_eu\LU_2012_chunk_5.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\FI_2011_chunk_3.csv to ..\zipped_files\subs_eu\FI_2011_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\SK_2020_chunk_3.csv to ..\zipped_files\subs_eu\SK_2020_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\PL_2014_chunk_1.csv to ..\zipped_files\subs_eu\PL_2014_chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\BA_2011_chunk_2.csv to ..\zipped_files\subs_eu\BA_2011_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\LV_2013_chunk_2.csv to ..\zipped_files\subs_eu\LV_2013_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\MT_2010_chunk_3.csv to ..\zipped_files\subs_eu\MT_2010_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\MT_2013_chunk_1.csv to ..\zipped_files\subs_eu\MT_2013_chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\HU_2018_chunk_3.csv to ..\zipped_files\subs_eu\HU_2018_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\BA_2007_chunk_2.csv to ..\zipped_files\subs_eu\BA_2007_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\GR_2019_chunk_1.csv to ..\zipped_files\subs_eu\GR_2019_chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\RO_2017_chunk_5.csv to ..\zipped_files\subs_eu\RO_2017_chunk_5.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\HR_2012_chunk_1.csv to ..\zipped_files\subs_eu\HR_2012_chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\HU_2012_chunk_4.csv to ..\zipped_files\subs_eu\HU_2012_chunk_4.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\BE_2022_chunk_4.csv to ..\zipped_files\subs_eu\BE_2022_chunk_4.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\RO_2019_chunk_3.csv to ..\zipped_files\subs_eu\RO_2019_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\CS_2014_chunk_5.csv to ..\zipped_files\subs_eu\CS_2014_chunk_5.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\CY_2008_chunk_3.csv to ..\zipped_files\subs_eu\CY_2008_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\IT_2008_chunk_1.csv to ..\zipped_files\subs_eu\IT_2008_chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\LU_2007_chunk_3.csv to ..\zipped_files\subs_eu\LU_2007_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\PL_2022_chunk_2.csv to ..\zipped_files\subs_eu\PL_2022_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\FI_2020_chunk_1.csv to ..\zipped_files\subs_eu\FI_2020_chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\MK_2012_chunk_4.csv to ..\zipped_files\subs_eu\MK_2012_chunk_4.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\DK_2010_chunk_5.csv to ..\zipped_files\subs_eu\DK_2010_chunk_5.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\FI_2016_chunk_4.csv to ..\zipped_files\subs_eu\FI_2016_chunk_4.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\EE_2010_chunk_2.csv to ..\zipped_files\subs_eu\EE_2010_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\AL_2020_chunk_5.csv to ..\zipped_files\subs_eu\AL_2020_chunk_5.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\DE_2008_chunk_4.csv to ..\zipped_files\subs_eu\DE_2008_chunk_4.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\ES_2015_chunk_4.csv to ..\zipped_files\subs_eu\ES_2015_chunk_4.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\MT_2021_chunk_1.csv to ..\zipped_files\subs_eu\MT_2021_chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\FR_2014_chunk_3.csv to ..\zipped_files\subs_eu\FR_2014_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\IE_2008_chunk_2.csv to ..\zipped_files\subs_eu\IE_2008_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\BG_2018_chunk_2.csv to ..\zipped_files\subs_eu\BG_2018_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\GR_2015_chunk_4.csv to ..\zipped_files\subs_eu\GR_2015_chunk_4.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\PL_2014_chunk_4.csv to ..\zipped_files\subs_eu\PL_2014_chunk_4.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\RO_2016_chunk_2.csv to ..\zipped_files\subs_eu\RO_2016_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\HU_2022_chunk_4.csv to ..\zipped_files\subs_eu\HU_2022_chunk_4.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\CZ_2019_chunk_1.csv to ..\zipped_files\subs_eu\CZ_2019_chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\NL_2018_chunk_1.csv to ..\zipped_files\subs_eu\NL_2018_chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\BE_2017_chunk_5.csv to ..\zipped_files\subs_eu\BE_2017_chunk_5.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\NL_2007_chunk_5.csv to ..\zipped_files\subs_eu\NL_2007_chunk_5.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\XK_2018_chunk_3.csv to ..\zipped_files\subs_eu\XK_2018_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\FR_2009_chunk_4.csv to ..\zipped_files\subs_eu\FR_2009_chunk_4.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\RO_2022_chunk_3.csv to ..\zipped_files\subs_eu\RO_2022_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\DK_2012_chunk_2.csv to ..\zipped_files\subs_eu\DK_2012_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\DE_2022_chunk_4.csv to ..\zipped_files\subs_eu\DE_2022_chunk_4.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\LT_2013_chunk_4.csv to ..\zipped_files\subs_eu\LT_2013_chunk_4.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\LU_2013_chunk_2.csv to ..\zipped_files\subs_eu\LU_2013_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\MT_2008_chunk_2.csv to ..\zipped_files\subs_eu\MT_2008_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\BG_2010_chunk_3.csv to ..\zipped_files\subs_eu\BG_2010_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\EE_2020_chunk_5.csv to ..\zipped_files\subs_eu\EE_2020_chunk_5.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\PT_2013_chunk_3.csv to ..\zipped_files\subs_eu\PT_2013_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\BE_2008_chunk_1.csv to ..\zipped_files\subs_eu\BE_2008_chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\PT_2022_chunk_1.csv to ..\zipped_files\subs_eu\PT_2022_chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\IE_2015_chunk_2.csv to ..\zipped_files\subs_eu\IE_2015_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\CZ_2016_chunk_2.csv to ..\zipped_files\subs_eu\CZ_2016_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\SE_2022_chunk_5.csv to ..\zipped_files\subs_eu\SE_2022_chunk_5.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\BA_2017_chunk_5.csv to ..\zipped_files\subs_eu\BA_2017_chunk_5.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\LV_2020_chunk_1.csv to ..\zipped_files\subs_eu\LV_2020_chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\BE_2021_chunk_3.csv to ..\zipped_files\subs_eu\BE_2021_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\XK_2022_chunk_1.csv to ..\zipped_files\subs_eu\XK_2022_chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\BA_2010_chunk_2.csv to ..\zipped_files\subs_eu\BA_2010_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\AT_2011_chunk_5.csv to ..\zipped_files\subs_eu\AT_2011_chunk_5.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\HR_2010_chunk_4.csv to ..\zipped_files\subs_eu\HR_2010_chunk_4.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\CS_2012_chunk_2.csv to ..\zipped_files\subs_eu\CS_2012_chunk_2.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\FI_2012_chunk_3.csv to ..\zipped_files\subs_eu\FI_2012_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\GR_2022_chunk_3.csv to ..\zipped_files\subs_eu\GR_2022_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\BE_2007_chunk_5.csv to ..\zipped_files\subs_eu\BE_2007_chunk_5.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\PL_2019_chunk_1.csv to ..\zipped_files\subs_eu\PL_2019_chunk_1.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\LT_2016_chunk_3.csv to ..\zipped_files\subs_eu\LT_2016_chunk_3.csv.gz
# Compressed ..\data_processed\\guo_subs_europee\\subs_eu\\HU_2022_chunk_2.csv to ..\zipped_files\subs_eu\HU_2022_chunk_2.csv.gz
