# %% [markdown]
# # CONVERT FILES WITH DUCK_DB

# %%
import pandas as pd
import duckdb
import os
import time
import numpy as np
from utils import time, data_processor, constants

# %%
OUTPUT_PATH = r"..\\data_processed\\guo_subs_world\\guos_eu\\" 

extra_eu = set(constants.americas + constants.asia + constants.africa + constants.oceania)

# %% [markdown]
# ## Define query

# %%
TEMP_TABLE_FIRMOGRAPHICS = "..\\data_processed\\firmographics_processed"
TEMP_TABLE_KEY_FINANCIALS_DETAILED = "..\\data_processed\\key_financials_detailed_processed"

def get_ownership_data(year, country, path=None):
    print(f"{country} - {year}...")

    COUNTRY_FIRMOGRAPHICS = TEMP_TABLE_FIRMOGRAPHICS + f"\\firmographics_{country}.parquet"
    COUNTRY_KEY_FINANCIALS = TEMP_TABLE_KEY_FINANCIALS_DETAILED + f"\\key_financials_detailed_{country}.parquet"

    query = f"""
        SELECT
            main.subsidiary_bvd_id,
            main.guo_25,
            {year} AS year,

            firmographics_sub.nuts2 AS subsidiary_nuts2,
            firmographics_sub.nace_rev_2_core_code_4_digits_ AS subsidiary_nace4,
            firmographics_guo.nuts2 AS guo_nuts2,
            firmographics_guo.nace_rev_2_core_code_4_digits_ AS guo_nace4,
            firmographics_guo.type_of_entity AS guo_type_of_entity,
            firmographics_guo.status AS guo_status,
            
            key_financials_detailed.number_of_employees
        FROM 
            '{path}' AS main

        LEFT JOIN 
            '{COUNTRY_KEY_FINANCIALS}' AS key_financials_detailed
        ON 
            main.guo_25 = key_financials_detailed.bvd_id_number
        AND 
            key_financials_detailed.year = {year}

        LEFT JOIN 
            '{COUNTRY_FIRMOGRAPHICS}' AS firmographics_sub
        ON 
            main.subsidiary_bvd_id = firmographics_sub.bvd_id_number

        LEFT JOIN 
            '{COUNTRY_FIRMOGRAPHICS}' AS firmographics_guo
        ON 
            main.guo_25 = firmographics_guo.bvd_id_number

        WHERE 
            main."type_of_relation" = 'GUO 25'
        AND 
            main."guo_25" LIKE '{country}%'
    """

    conn = duckdb.connect()
    df = conn.execute(query).fetchdf()
    return df

# %%
def split_in_chunks(df, n_chunks):
    indices = np.array_split(df.index, n_chunks)
    slices = [df.iloc[idx] for idx in indices]
    return slices

@time.time_it
def fetch_and_convert_to_excel(year, country, path, output_path):
    df = get_ownership_data(year, country, path)
    os.makedirs(output_path, exist_ok=True)
    slices = data_processor.split_in_chunks(df, 5)

    for i, s in enumerate(slices):
        s.to_csv(f"{output_path}\\{country}_{year}_chunk_{i+1}.csv", index=False)
        print(f"Data for {country} - {year} - slice_{i+1} has been converted.")

# %% [markdown]
# ### Test

# %%
country = "AL"
year = "2017"
path = "..\\data_raw\\ownership_history\\links_2017\\*.parquet"

df = get_ownership_data(
    path=path,
    year=year,
    country=country,
)
# Out:
# AL - 2017...

# %%
import time
import json

errors = {}

if not os.path.exists(OUTPUT_PATH):
    print(f"Folder does not exist: {OUTPUT_PATH}")
    os.makedirs(OUTPUT_PATH, exist_ok=True)

total_start = time.time()
start_time = time.time()

# for country in asia+oceania+
for country in extra_eu:
    for year in range(2007, 2023):
        year = str(year)
        try:
            path = f"..\\data_raw\\ownership_history\\links_{year}\\*.parquet"
            fetch_and_convert_to_excel(year, country, path, OUTPUT_PATH)  
            end_time = time.time()
            duration = end_time - start_time
            print(f"Data for {country} - {year} has been converted to Stata in {duration:.2f} seconds.")
        except Exception as e:
            errors[f"{country} - {year}"] = str(e)
            print(f"Error {country} - {year}")
            continue


end_time = time.time()
duration = end_time - start_time
total_end = time.time()
total_duration = total_end - total_start
print(f"Total execution time: {total_duration:.2f} seconds.")

with open("errors/errors_guos_world.json", "w") as f:
    json.dump(errors, f)
# Out:
# DZ - 2007...
# Data for DZ - 2007 - slice_1 has been converted.
# Data for DZ - 2007 - slice_2 has been converted.
# Data for DZ - 2007 - slice_3 has been converted.
# Data for DZ - 2007 - slice_4 has been converted.
# Data for DZ - 2007 - slice_5 has been converted.
# Execution time: 7.8114 seconds
# Data for DZ - 2007 has been converted to Stata in 7.81 seconds.
# DZ - 2008...
# Data for DZ - 2008 - slice_1 has been converted.
# Data for DZ - 2008 - slice_2 has been converted.
# Data for DZ - 2008 - slice_3 has been converted.
# Data for DZ - 2008 - slice_4 has been converted.
# Data for DZ - 2008 - slice_5 has been converted.
# Execution time: 8.2165 seconds
# Data for DZ - 2008 has been converted to Stata in 16.03 seconds.
# DZ - 2009...
# Data for DZ - 2009 - slice_1 has been converted.
# Data for DZ - 2009 - slice_2 has been converted.
# Data for DZ - 2009 - slice_3 has been converted.
# Data for DZ - 2009 - slice_4 has been converted.
# Data for DZ - 2009 - slice_5 has been converted.
# Execution time: 9.2226 seconds
# Data for DZ - 2009 has been converted to Stata in 25.25 seconds.
# DZ - 2010...
# Data for DZ - 2010 - slice_1 has been converted.
# Data for DZ - 2010 - slice_2 has been converted.
# Data for DZ - 2010 - slice_3 has been converted.
# Data for DZ - 2010 - slice_4 has been converted.
# Data for DZ - 2010 - slice_5 has been converted.
# Execution time: 10.3477 seconds
# Data for DZ - 2010 has been converted to Stata in 35.60 seconds.
# DZ - 2011...
# Data for DZ - 2011 - slice_1 has been converted.
# Data for DZ - 2011 - slice_2 has been converted.
# Data for DZ - 2011 - slice_3 has been converted.
# Data for DZ - 2011 - slice_4 has been converted.
# Data for DZ - 2011 - slice_5 has been converted.
# Execution time: 12.1535 seconds
# Data for DZ - 2011 has been converted to Stata in 47.75 seconds.
# DZ - 2012...
# Data for DZ - 2012 - slice_1 has been converted.
# Data for DZ - 2012 - slice_2 has been converted.
# Data for DZ - 2012 - slice_3 has been converted.
# Data for DZ - 2012 - slice_4 has been converted.
# Data for DZ - 2012 - slice_5 has been converted.
# Execution time: 14.0190 seconds
# Data for DZ - 2012 has been converted to Stata in 61.77 seconds.
# DZ - 2013...
# Data for DZ - 2013 - slice_1 has been converted.
# Data for DZ - 2013 - slice_2 has been converted.
# Data for DZ - 2013 - slice_3 has been converted.
# Data for DZ - 2013 - slice_4 has been converted.
# Data for DZ - 2013 - slice_5 has been converted.
# Execution time: 14.1712 seconds
# Data for DZ - 2013 has been converted to Stata in 75.94 seconds.
# DZ - 2014...
# Data for DZ - 2014 - slice_1 has been converted.
# Data for DZ - 2014 - slice_2 has been converted.
# Data for DZ - 2014 - slice_3 has been converted.
# Data for DZ - 2014 - slice_4 has been converted.
# Data for DZ - 2014 - slice_5 has been converted.
# Execution time: 15.0256 seconds
# Data for DZ - 2014 has been converted to Stata in 90.97 seconds.
# DZ - 2015...
# Data for DZ - 2015 - slice_1 has been converted.
# Data for DZ - 2015 - slice_2 has been converted.
# Data for DZ - 2015 - slice_3 has been converted.
# Data for DZ - 2015 - slice_4 has been converted.
# Data for DZ - 2015 - slice_5 has been converted.
# Execution time: 18.1363 seconds
# Data for DZ - 2015 has been converted to Stata in 109.10 seconds.
# DZ - 2016...
# Data for DZ - 2016 - slice_1 has been converted.
# Data for DZ - 2016 - slice_2 has been converted.
# Data for DZ - 2016 - slice_3 has been converted.
# Data for DZ - 2016 - slice_4 has been converted.
# Data for DZ - 2016 - slice_5 has been converted.
# Execution time: 19.6546 seconds
# Data for DZ - 2016 has been converted to Stata in 128.76 seconds.
# DZ - 2017...
# Data for DZ - 2017 - slice_1 has been converted.
# Data for DZ - 2017 - slice_2 has been converted.
# Data for DZ - 2017 - slice_3 has been converted.
# Data for DZ - 2017 - slice_4 has been converted.
# Data for DZ - 2017 - slice_5 has been converted.
# Execution time: 22.7814 seconds
# Data for DZ - 2017 has been converted to Stata in 151.54 seconds.
# DZ - 2018...
# Data for DZ - 2018 - slice_1 has been converted.
# Data for DZ - 2018 - slice_2 has been converted.
# Data for DZ - 2018 - slice_3 has been converted.
# Data for DZ - 2018 - slice_4 has been converted.
# Data for DZ - 2018 - slice_5 has been converted.
# Execution time: 27.9843 seconds
# Data for DZ - 2018 has been converted to Stata in 179.52 seconds.
# DZ - 2019...
# Data for DZ - 2019 - slice_1 has been converted.
# Data for DZ - 2019 - slice_2 has been converted.
# Data for DZ - 2019 - slice_3 has been converted.
# Data for DZ - 2019 - slice_4 has been converted.
# Data for DZ - 2019 - slice_5 has been converted.
# Execution time: 115.1320 seconds
# Data for DZ - 2019 has been converted to Stata in 294.66 seconds.
# DZ - 2020...
# Data for DZ - 2020 - slice_1 has been converted.
# Data for DZ - 2020 - slice_2 has been converted.
# Data for DZ - 2020 - slice_3 has been converted.
# Data for DZ - 2020 - slice_4 has been converted.
# Data for DZ - 2020 - slice_5 has been converted.
# Execution time: 126.6406 seconds
# Data for DZ - 2020 has been converted to Stata in 421.30 seconds.
# DZ - 2021...
# Data for DZ - 2021 - slice_1 has been converted.
# Data for DZ - 2021 - slice_2 has been converted.
# Data for DZ - 2021 - slice_3 has been converted.
# Data for DZ - 2021 - slice_4 has been converted.
# Data for DZ - 2021 - slice_5 has been converted.
# Execution time: 124.4920 seconds
# Data for DZ - 2021 has been converted to Stata in 545.79 seconds.
# DZ - 2022...
# Data for DZ - 2022 - slice_1 has been converted.
# Data for DZ - 2022 - slice_2 has been converted.
# Data for DZ - 2022 - slice_3 has been converted.
# Data for DZ - 2022 - slice_4 has been converted.
# Data for DZ - 2022 - slice_5 has been converted.
# Execution time: 130.3529 seconds
# Data for DZ - 2022 has been converted to Stata in 676.14 seconds.
# AO - 2007...
# Data for AO - 2007 - slice_1 has been converted.
# Data for AO - 2007 - slice_2 has been converted.
# Data for AO - 2007 - slice_3 has been converted.
# Data for AO - 2007 - slice_4 has been converted.
# Data for AO - 2007 - slice_5 has been converted.
# Execution time: 5.2051 seconds
# Data for AO - 2007 has been converted to Stata in 681.35 seconds.
# AO - 2008...
# Data for AO - 2008 - slice_1 has been converted.
# Data for AO - 2008 - slice_2 has been converted.
# Data for AO - 2008 - slice_3 has been converted.
# Data for AO - 2008 - slice_4 has been converted.
# Data for AO - 2008 - slice_5 has been converted.
# Execution time: 5.4551 seconds
# Data for AO - 2008 has been converted to Stata in 686.80 seconds.
# AO - 2009...
# Data for AO - 2009 - slice_1 has been converted.
# Data for AO - 2009 - slice_2 has been converted.
# Data for AO - 2009 - slice_3 has been converted.
# Data for AO - 2009 - slice_4 has been converted.
# Data for AO - 2009 - slice_5 has been converted.
# Execution time: 6.4960 seconds
# Data for AO - 2009 has been converted to Stata in 693.30 seconds.
# AO - 2010...
# Data for AO - 2010 - slice_1 has been converted.
# Data for AO - 2010 - slice_2 has been converted.
# Data for AO - 2010 - slice_3 has been converted.
# Data for AO - 2010 - slice_4 has been converted.
# Data for AO - 2010 - slice_5 has been converted.
# Execution time: 7.2448 seconds
# Data for AO - 2010 has been converted to Stata in 700.54 seconds.
# AO - 2011...
# Data for AO - 2011 - slice_1 has been converted.
# Data for AO - 2011 - slice_2 has been converted.
# Data for AO - 2011 - slice_3 has been converted.
# Data for AO - 2011 - slice_4 has been converted.
# Data for AO - 2011 - slice_5 has been converted.
# Execution time: 8.6560 seconds
# Data for AO - 2011 has been converted to Stata in 709.20 seconds.
# AO - 2012...
# Data for AO - 2012 - slice_1 has been converted.
# Data for AO - 2012 - slice_2 has been converted.
# Data for AO - 2012 - slice_3 has been converted.
# Data for AO - 2012 - slice_4 has been converted.
# Data for AO - 2012 - slice_5 has been converted.
# Execution time: 10.1044 seconds
# Data for AO - 2012 has been converted to Stata in 719.31 seconds.
# AO - 2013...
# Data for AO - 2013 - slice_1 has been converted.
# Data for AO - 2013 - slice_2 has been converted.
# Data for AO - 2013 - slice_3 has been converted.
# Data for AO - 2013 - slice_4 has been converted.
# Data for AO - 2013 - slice_5 has been converted.
# Execution time: 11.0211 seconds
# Data for AO - 2013 has been converted to Stata in 730.33 seconds.
# AO - 2014...
# Data for AO - 2014 - slice_1 has been converted.
# Data for AO - 2014 - slice_2 has been converted.
# Data for AO - 2014 - slice_3 has been converted.
# Data for AO - 2014 - slice_4 has been converted.
# Data for AO - 2014 - slice_5 has been converted.
# Execution time: 12.2988 seconds
# Data for AO - 2014 has been converted to Stata in 742.63 seconds.
# AO - 2015...
# Data for AO - 2015 - slice_1 has been converted.
# Data for AO - 2015 - slice_2 has been converted.
# Data for AO - 2015 - slice_3 has been converted.
# Data for AO - 2015 - slice_4 has been converted.
# Data for AO - 2015 - slice_5 has been converted.
# Execution time: 14.6555 seconds
# Data for AO - 2015 has been converted to Stata in 757.28 seconds.
# AO - 2016...
# Data for AO - 2016 - slice_1 has been converted.
# Data for AO - 2016 - slice_2 has been converted.
# Data for AO - 2016 - slice_3 has been converted.
# Data for AO - 2016 - slice_4 has been converted.
# Data for AO - 2016 - slice_5 has been converted.
# Execution time: 16.9196 seconds
# Data for AO - 2016 has been converted to Stata in 774.20 seconds.
# AO - 2017...
# Data for AO - 2017 - slice_1 has been converted.
# Data for AO - 2017 - slice_2 has been converted.
# Data for AO - 2017 - slice_3 has been converted.
# Data for AO - 2017 - slice_4 has been converted.
# Data for AO - 2017 - slice_5 has been converted.
# Execution time: 19.3835 seconds
# Data for AO - 2017 has been converted to Stata in 793.58 seconds.
# AO - 2018...
# Data for AO - 2018 - slice_1 has been converted.
# Data for AO - 2018 - slice_2 has been converted.
# Data for AO - 2018 - slice_3 has been converted.
# Data for AO - 2018 - slice_4 has been converted.
# Data for AO - 2018 - slice_5 has been converted.
# Execution time: 21.3879 seconds
# Data for AO - 2018 has been converted to Stata in 814.97 seconds.
# AO - 2019...
# Data for AO - 2019 - slice_1 has been converted.
# Data for AO - 2019 - slice_2 has been converted.
# Data for AO - 2019 - slice_3 has been converted.
# Data for AO - 2019 - slice_4 has been converted.
# Data for AO - 2019 - slice_5 has been converted.
# Execution time: 24.1313 seconds
# Data for AO - 2019 has been converted to Stata in 839.10 seconds.
# AO - 2020...
# Data for AO - 2020 - slice_1 has been converted.
# Data for AO - 2020 - slice_2 has been converted.
# Data for AO - 2020 - slice_3 has been converted.
# Data for AO - 2020 - slice_4 has been converted.
# Data for AO - 2020 - slice_5 has been converted.
# Execution time: 25.1348 seconds
# Data for AO - 2020 has been converted to Stata in 864.24 seconds.
# AO - 2021...
# Data for AO - 2021 - slice_1 has been converted.
# Data for AO - 2021 - slice_2 has been converted.
# Data for AO - 2021 - slice_3 has been converted.
# Data for AO - 2021 - slice_4 has been converted.
# Data for AO - 2021 - slice_5 has been converted.
# Execution time: 27.0054 seconds
# Data for AO - 2021 has been converted to Stata in 891.24 seconds.
# AO - 2022...
# Data for AO - 2022 - slice_1 has been converted.
# Data for AO - 2022 - slice_2 has been converted.
# Data for AO - 2022 - slice_3 has been converted.
# Data for AO - 2022 - slice_4 has been converted.
# Data for AO - 2022 - slice_5 has been converted.
# Execution time: 27.5448 seconds
# Data for AO - 2022 has been converted to Stata in 918.79 seconds.
# BJ - 2007...
# Data for BJ - 2007 - slice_1 has been converted.
# Data for BJ - 2007 - slice_2 has been converted.
# Data for BJ - 2007 - slice_3 has been converted.
# Data for BJ - 2007 - slice_4 has been converted.
# Data for BJ - 2007 - slice_5 has been converted.
# Execution time: 5.1514 seconds
# Data for BJ - 2007 has been converted to Stata in 923.94 seconds.
# BJ - 2008...
# Data for BJ - 2008 - slice_1 has been converted.
# Data for BJ - 2008 - slice_2 has been converted.
# Data for BJ - 2008 - slice_3 has been converted.
# Data for BJ - 2008 - slice_4 has been converted.
# Data for BJ - 2008 - slice_5 has been converted.
# Execution time: 5.5577 seconds
# Data for BJ - 2008 has been converted to Stata in 929.50 seconds.
# BJ - 2009...
# Data for BJ - 2009 - slice_1 has been converted.
# Data for BJ - 2009 - slice_2 has been converted.
# Data for BJ - 2009 - slice_3 has been converted.
# Data for BJ - 2009 - slice_4 has been converted.
# Data for BJ - 2009 - slice_5 has been converted.
# Execution time: 6.6197 seconds
# Data for BJ - 2009 has been converted to Stata in 936.12 seconds.
# BJ - 2010...
# Data for BJ - 2010 - slice_1 has been converted.
# Data for BJ - 2010 - slice_2 has been converted.
# Data for BJ - 2010 - slice_3 has been converted.
# Data for BJ - 2010 - slice_4 has been converted.
# Data for BJ - 2010 - slice_5 has been converted.
# Execution time: 6.8482 seconds
# Data for BJ - 2010 has been converted to Stata in 942.97 seconds.
# BJ - 2011...
# Data for BJ - 2011 - slice_1 has been converted.
# Data for BJ - 2011 - slice_2 has been converted.
# Data for BJ - 2011 - slice_3 has been converted.
# Data for BJ - 2011 - slice_4 has been converted.
# Data for BJ - 2011 - slice_5 has been converted.
# Execution time: 8.1295 seconds
# Data for BJ - 2011 has been converted to Stata in 951.10 seconds.
# BJ - 2012...
# Data for BJ - 2012 - slice_1 has been converted.
# Data for BJ - 2012 - slice_2 has been converted.
# Data for BJ - 2012 - slice_3 has been converted.
# Data for BJ - 2012 - slice_4 has been converted.
# Data for BJ - 2012 - slice_5 has been converted.
# Execution time: 9.2419 seconds
# Data for BJ - 2012 has been converted to Stata in 960.34 seconds.
# BJ - 2013...
# Data for BJ - 2013 - slice_1 has been converted.
# Data for BJ - 2013 - slice_2 has been converted.
# Data for BJ - 2013 - slice_3 has been converted.
# Data for BJ - 2013 - slice_4 has been converted.
# Data for BJ - 2013 - slice_5 has been converted.
# Execution time: 10.3452 seconds
# Data for BJ - 2013 has been converted to Stata in 970.68 seconds.
# BJ - 2014...
# Data for BJ - 2014 - slice_1 has been converted.
# Data for BJ - 2014 - slice_2 has been converted.
# Data for BJ - 2014 - slice_3 has been converted.
# Data for BJ - 2014 - slice_4 has been converted.
# Data for BJ - 2014 - slice_5 has been converted.
# Execution time: 11.2393 seconds
# Data for BJ - 2014 has been converted to Stata in 981.92 seconds.
# BJ - 2015...
# Data for BJ - 2015 - slice_1 has been converted.
# Data for BJ - 2015 - slice_2 has been converted.
# Data for BJ - 2015 - slice_3 has been converted.
# Data for BJ - 2015 - slice_4 has been converted.
# Data for BJ - 2015 - slice_5 has been converted.
# Execution time: 12.4230 seconds
# Data for BJ - 2015 has been converted to Stata in 994.34 seconds.
# BJ - 2016...
# Data for BJ - 2016 - slice_1 has been converted.
# Data for BJ - 2016 - slice_2 has been converted.
# Data for BJ - 2016 - slice_3 has been converted.
# Data for BJ - 2016 - slice_4 has been converted.
# Data for BJ - 2016 - slice_5 has been converted.
# Execution time: 14.5372 seconds
# Data for BJ - 2016 has been converted to Stata in 1008.88 seconds.
# BJ - 2017...
# Data for BJ - 2017 - slice_1 has been converted.
# Data for BJ - 2017 - slice_2 has been converted.
# Data for BJ - 2017 - slice_3 has been converted.
# Data for BJ - 2017 - slice_4 has been converted.
# Data for BJ - 2017 - slice_5 has been converted.
# Execution time: 16.8600 seconds
# Data for BJ - 2017 has been converted to Stata in 1025.74 seconds.
# BJ - 2018...
# Data for BJ - 2018 - slice_1 has been converted.
# Data for BJ - 2018 - slice_2 has been converted.
# Data for BJ - 2018 - slice_3 has been converted.
# Data for BJ - 2018 - slice_4 has been converted.
# Data for BJ - 2018 - slice_5 has been converted.
# Execution time: 20.3671 seconds
# Data for BJ - 2018 has been converted to Stata in 1046.11 seconds.
# BJ - 2019...
# Data for BJ - 2019 - slice_1 has been converted.
# Data for BJ - 2019 - slice_2 has been converted.
# Data for BJ - 2019 - slice_3 has been converted.
# Data for BJ - 2019 - slice_4 has been converted.
# Data for BJ - 2019 - slice_5 has been converted.
# Execution time: 22.8384 seconds
# Data for BJ - 2019 has been converted to Stata in 1068.95 seconds.
# BJ - 2020...
# Data for BJ - 2020 - slice_1 has been converted.
# Data for BJ - 2020 - slice_2 has been converted.
# Data for BJ - 2020 - slice_3 has been converted.
# Data for BJ - 2020 - slice_4 has been converted.
# Data for BJ - 2020 - slice_5 has been converted.
# Execution time: 23.7143 seconds
# Data for BJ - 2020 has been converted to Stata in 1092.66 seconds.
# BJ - 2021...
# Data for BJ - 2021 - slice_1 has been converted.
# Data for BJ - 2021 - slice_2 has been converted.
# Data for BJ - 2021 - slice_3 has been converted.
# Data for BJ - 2021 - slice_4 has been converted.
# Data for BJ - 2021 - slice_5 has been converted.
# Execution time: 25.0264 seconds
# Data for BJ - 2021 has been converted to Stata in 1117.69 seconds.
# BJ - 2022...
# Data for BJ - 2022 - slice_1 has been converted.
# Data for BJ - 2022 - slice_2 has been converted.
# Data for BJ - 2022 - slice_3 has been converted.
# Data for BJ - 2022 - slice_4 has been converted.
# Data for BJ - 2022 - slice_5 has been converted.
# Execution time: 25.6669 seconds
# Data for BJ - 2022 has been converted to Stata in 1143.36 seconds.
# BW - 2007...
# Data for BW - 2007 - slice_1 has been converted.
# Data for BW - 2007 - slice_2 has been converted.
# Data for BW - 2007 - slice_3 has been converted.
# Data for BW - 2007 - slice_4 has been converted.
# Data for BW - 2007 - slice_5 has been converted.
# Execution time: 5.2313 seconds
# Data for BW - 2007 has been converted to Stata in 1148.59 seconds.
# BW - 2008...
# Data for BW - 2008 - slice_1 has been converted.
# Data for BW - 2008 - slice_2 has been converted.
# Data for BW - 2008 - slice_3 has been converted.
# Data for BW - 2008 - slice_4 has been converted.
# Data for BW - 2008 - slice_5 has been converted.
# Execution time: 5.7691 seconds
# Data for BW - 2008 has been converted to Stata in 1154.36 seconds.
# BW - 2009...
# Data for BW - 2009 - slice_1 has been converted.
# Data for BW - 2009 - slice_2 has been converted.
# Data for BW - 2009 - slice_3 has been converted.
# Data for BW - 2009 - slice_4 has been converted.
# Data for BW - 2009 - slice_5 has been converted.
# Execution time: 6.6040 seconds
# Data for BW - 2009 has been converted to Stata in 1160.96 seconds.
# BW - 2010...
# Data for BW - 2010 - slice_1 has been converted.
# Data for BW - 2010 - slice_2 has been converted.
# Data for BW - 2010 - slice_3 has been converted.
# Data for BW - 2010 - slice_4 has been converted.
# Data for BW - 2010 - slice_5 has been converted.
# Execution time: 7.4221 seconds
# Data for BW - 2010 has been converted to Stata in 1168.38 seconds.
# BW - 2011...
# Data for BW - 2011 - slice_1 has been converted.
# Data for BW - 2011 - slice_2 has been converted.
# Data for BW - 2011 - slice_3 has been converted.
# Data for BW - 2011 - slice_4 has been converted.
# Data for BW - 2011 - slice_5 has been converted.
# Execution time: 8.5367 seconds
# Data for BW - 2011 has been converted to Stata in 1176.92 seconds.
# BW - 2012...
# Data for BW - 2012 - slice_1 has been converted.
# Data for BW - 2012 - slice_2 has been converted.
# Data for BW - 2012 - slice_3 has been converted.
# Data for BW - 2012 - slice_4 has been converted.
# Data for BW - 2012 - slice_5 has been converted.
# Execution time: 9.8576 seconds
# Data for BW - 2012 has been converted to Stata in 1186.78 seconds.
# BW - 2013...
# Data for BW - 2013 - slice_1 has been converted.
# Data for BW - 2013 - slice_2 has been converted.
# Data for BW - 2013 - slice_3 has been converted.
# Data for BW - 2013 - slice_4 has been converted.
# Data for BW - 2013 - slice_5 has been converted.
# Execution time: 11.0277 seconds
# Data for BW - 2013 has been converted to Stata in 1197.80 seconds.
# BW - 2014...
# Data for BW - 2014 - slice_1 has been converted.
# Data for BW - 2014 - slice_2 has been converted.
# Data for BW - 2014 - slice_3 has been converted.
# Data for BW - 2014 - slice_4 has been converted.
# Data for BW - 2014 - slice_5 has been converted.
# Execution time: 12.1656 seconds
# Data for BW - 2014 has been converted to Stata in 1209.97 seconds.
# BW - 2015...
# Data for BW - 2015 - slice_1 has been converted.
# Data for BW - 2015 - slice_2 has been converted.
# Data for BW - 2015 - slice_3 has been converted.
# Data for BW - 2015 - slice_4 has been converted.
# Data for BW - 2015 - slice_5 has been converted.
# Execution time: 13.7413 seconds
# Data for BW - 2015 has been converted to Stata in 1223.71 seconds.
# BW - 2016...
# Data for BW - 2016 - slice_1 has been converted.
# Data for BW - 2016 - slice_2 has been converted.
# Data for BW - 2016 - slice_3 has been converted.
# Data for BW - 2016 - slice_4 has been converted.
# Data for BW - 2016 - slice_5 has been converted.
# Execution time: 16.4184 seconds
# Data for BW - 2016 has been converted to Stata in 1240.13 seconds.
# BW - 2017...
# Data for BW - 2017 - slice_1 has been converted.
# Data for BW - 2017 - slice_2 has been converted.
# Data for BW - 2017 - slice_3 has been converted.
# Data for BW - 2017 - slice_4 has been converted.
# Data for BW - 2017 - slice_5 has been converted.
# Execution time: 17.9957 seconds
# Data for BW - 2017 has been converted to Stata in 1258.13 seconds.
# BW - 2018...
# Data for BW - 2018 - slice_1 has been converted.
# Data for BW - 2018 - slice_2 has been converted.
# Data for BW - 2018 - slice_3 has been converted.
# Data for BW - 2018 - slice_4 has been converted.
# Data for BW - 2018 - slice_5 has been converted.
# Execution time: 22.2886 seconds
# Data for BW - 2018 has been converted to Stata in 1280.41 seconds.
# BW - 2019...
# Data for BW - 2019 - slice_1 has been converted.
# Data for BW - 2019 - slice_2 has been converted.
# Data for BW - 2019 - slice_3 has been converted.
# Data for BW - 2019 - slice_4 has been converted.
# Data for BW - 2019 - slice_5 has been converted.
# Execution time: 23.7107 seconds
# Data for BW - 2019 has been converted to Stata in 1304.12 seconds.
# BW - 2020...
# Data for BW - 2020 - slice_1 has been converted.
# Data for BW - 2020 - slice_2 has been converted.
# Data for BW - 2020 - slice_3 has been converted.
# Data for BW - 2020 - slice_4 has been converted.
# Data for BW - 2020 - slice_5 has been converted.
# Execution time: 24.6474 seconds
# Data for BW - 2020 has been converted to Stata in 1328.77 seconds.
# BW - 2021...
# Data for BW - 2021 - slice_1 has been converted.
# Data for BW - 2021 - slice_2 has been converted.
# Data for BW - 2021 - slice_3 has been converted.
# Data for BW - 2021 - slice_4 has been converted.
# Data for BW - 2021 - slice_5 has been converted.
# Execution time: 26.6964 seconds
# Data for BW - 2021 has been converted to Stata in 1355.47 seconds.
# BW - 2022...
# Data for BW - 2022 - slice_1 has been converted.
# Data for BW - 2022 - slice_2 has been converted.
# Data for BW - 2022 - slice_3 has been converted.
# Data for BW - 2022 - slice_4 has been converted.
# Data for BW - 2022 - slice_5 has been converted.
# Execution time: 28.5864 seconds
# Data for BW - 2022 has been converted to Stata in 1384.05 seconds.
# IO - 2007...
# Data for IO - 2007 - slice_1 has been converted.
# Data for IO - 2007 - slice_2 has been converted.
# Data for IO - 2007 - slice_3 has been converted.
# Data for IO - 2007 - slice_4 has been converted.
# Data for IO - 2007 - slice_5 has been converted.
# Execution time: 4.8093 seconds
# Data for IO - 2007 has been converted to Stata in 1388.86 seconds.
# IO - 2008...
# Data for IO - 2008 - slice_1 has been converted.
# Data for IO - 2008 - slice_2 has been converted.
# Data for IO - 2008 - slice_3 has been converted.
# Data for IO - 2008 - slice_4 has been converted.
# Data for IO - 2008 - slice_5 has been converted.
# Execution time: 5.1121 seconds
# Data for IO - 2008 has been converted to Stata in 1393.98 seconds.
# IO - 2009...
# Data for IO - 2009 - slice_1 has been converted.
# Data for IO - 2009 - slice_2 has been converted.
# Data for IO - 2009 - slice_3 has been converted.
# Data for IO - 2009 - slice_4 has been converted.
# Data for IO - 2009 - slice_5 has been converted.
# Execution time: 6.3671 seconds
# Data for IO - 2009 has been converted to Stata in 1400.34 seconds.
# IO - 2010...
# Data for IO - 2010 - slice_1 has been converted.
# Data for IO - 2010 - slice_2 has been converted.
# Data for IO - 2010 - slice_3 has been converted.
# Data for IO - 2010 - slice_4 has been converted.
# Data for IO - 2010 - slice_5 has been converted.
# Execution time: 6.5661 seconds
# Data for IO - 2010 has been converted to Stata in 1406.91 seconds.
# IO - 2011...
# Data for IO - 2011 - slice_1 has been converted.
# Data for IO - 2011 - slice_2 has been converted.
# Data for IO - 2011 - slice_3 has been converted.
# Data for IO - 2011 - slice_4 has been converted.
# Data for IO - 2011 - slice_5 has been converted.
# Execution time: 7.7477 seconds
# Data for IO - 2011 has been converted to Stata in 1414.66 seconds.
# IO - 2012...
# Data for IO - 2012 - slice_1 has been converted.
# Data for IO - 2012 - slice_2 has been converted.
# Data for IO - 2012 - slice_3 has been converted.
# Data for IO - 2012 - slice_4 has been converted.
# Data for IO - 2012 - slice_5 has been converted.
# Execution time: 9.0678 seconds
# Data for IO - 2012 has been converted to Stata in 1423.73 seconds.
# IO - 2013...
# Data for IO - 2013 - slice_1 has been converted.
# Data for IO - 2013 - slice_2 has been converted.
# Data for IO - 2013 - slice_3 has been converted.
# Data for IO - 2013 - slice_4 has been converted.
# Data for IO - 2013 - slice_5 has been converted.
# Execution time: 9.6890 seconds
# Data for IO - 2013 has been converted to Stata in 1433.41 seconds.
# IO - 2014...
# Data for IO - 2014 - slice_1 has been converted.
# Data for IO - 2014 - slice_2 has been converted.
# Data for IO - 2014 - slice_3 has been converted.
# Data for IO - 2014 - slice_4 has been converted.
# Data for IO - 2014 - slice_5 has been converted.
# Execution time: 10.5174 seconds
# Data for IO - 2014 has been converted to Stata in 1443.93 seconds.
# IO - 2015...
# Data for IO - 2015 - slice_1 has been converted.
# Data for IO - 2015 - slice_2 has been converted.
# Data for IO - 2015 - slice_3 has been converted.
# Data for IO - 2015 - slice_4 has been converted.
# Data for IO - 2015 - slice_5 has been converted.
# Execution time: 12.1531 seconds
# Data for IO - 2015 has been converted to Stata in 1456.08 seconds.
# IO - 2016...
# Data for IO - 2016 - slice_1 has been converted.
# Data for IO - 2016 - slice_2 has been converted.
# Data for IO - 2016 - slice_3 has been converted.
# Data for IO - 2016 - slice_4 has been converted.
# Data for IO - 2016 - slice_5 has been converted.
# Execution time: 14.0207 seconds
# Data for IO - 2016 has been converted to Stata in 1470.11 seconds.
# IO - 2017...
# Data for IO - 2017 - slice_1 has been converted.
# Data for IO - 2017 - slice_2 has been converted.
# Data for IO - 2017 - slice_3 has been converted.
# Data for IO - 2017 - slice_4 has been converted.
# Data for IO - 2017 - slice_5 has been converted.
# Execution time: 15.7093 seconds
# Data for IO - 2017 has been converted to Stata in 1485.81 seconds.
# IO - 2018...
# Data for IO - 2018 - slice_1 has been converted.
# Data for IO - 2018 - slice_2 has been converted.
# Data for IO - 2018 - slice_3 has been converted.
# Data for IO - 2018 - slice_4 has been converted.
# Data for IO - 2018 - slice_5 has been converted.
# Execution time: 19.4266 seconds
# Data for IO - 2018 has been converted to Stata in 1505.24 seconds.
# IO - 2019...
# Data for IO - 2019 - slice_1 has been converted.
# Data for IO - 2019 - slice_2 has been converted.
# Data for IO - 2019 - slice_3 has been converted.
# Data for IO - 2019 - slice_4 has been converted.
# Data for IO - 2019 - slice_5 has been converted.
# Execution time: 21.5803 seconds
# Data for IO - 2019 has been converted to Stata in 1526.82 seconds.
# IO - 2020...
# Data for IO - 2020 - slice_1 has been converted.
# Data for IO - 2020 - slice_2 has been converted.
# Data for IO - 2020 - slice_3 has been converted.
# Data for IO - 2020 - slice_4 has been converted.
# Data for IO - 2020 - slice_5 has been converted.
# Execution time: 22.0620 seconds
# Data for IO - 2020 has been converted to Stata in 1548.88 seconds.
# IO - 2021...
# Data for IO - 2021 - slice_1 has been converted.
# Data for IO - 2021 - slice_2 has been converted.
# Data for IO - 2021 - slice_3 has been converted.
# Data for IO - 2021 - slice_4 has been converted.
# Data for IO - 2021 - slice_5 has been converted.
# Execution time: 23.4378 seconds
# Data for IO - 2021 has been converted to Stata in 1572.32 seconds.
# IO - 2022...
# Data for IO - 2022 - slice_1 has been converted.
# Data for IO - 2022 - slice_2 has been converted.
# Data for IO - 2022 - slice_3 has been converted.
# Data for IO - 2022 - slice_4 has been converted.
# Data for IO - 2022 - slice_5 has been converted.
# Execution time: 24.2695 seconds
# Data for IO - 2022 has been converted to Stata in 1596.59 seconds.
# BF - 2007...
# Data for BF - 2007 - slice_1 has been converted.
# Data for BF - 2007 - slice_2 has been converted.
# Data for BF - 2007 - slice_3 has been converted.
# Data for BF - 2007 - slice_4 has been converted.
# Data for BF - 2007 - slice_5 has been converted.
# Execution time: 5.1471 seconds
# Data for BF - 2007 has been converted to Stata in 1601.74 seconds.
# BF - 2008...
# Data for BF - 2008 - slice_1 has been converted.
# Data for BF - 2008 - slice_2 has been converted.
# Data for BF - 2008 - slice_3 has been converted.
# Data for BF - 2008 - slice_4 has been converted.
# Data for BF - 2008 - slice_5 has been converted.
# Execution time: 5.3122 seconds
# Data for BF - 2008 has been converted to Stata in 1607.05 seconds.
# BF - 2009...
# Data for BF - 2009 - slice_1 has been converted.
# Data for BF - 2009 - slice_2 has been converted.
# Data for BF - 2009 - slice_3 has been converted.
# Data for BF - 2009 - slice_4 has been converted.
# Data for BF - 2009 - slice_5 has been converted.
# Execution time: 6.0001 seconds
# Data for BF - 2009 has been converted to Stata in 1613.05 seconds.
# BF - 2010...
# Data for BF - 2010 - slice_1 has been converted.
# Data for BF - 2010 - slice_2 has been converted.
# Data for BF - 2010 - slice_3 has been converted.
# Data for BF - 2010 - slice_4 has been converted.
# Data for BF - 2010 - slice_5 has been converted.
# Execution time: 6.9078 seconds
# Data for BF - 2010 has been converted to Stata in 1619.96 seconds.
# BF - 2011...
# Data for BF - 2011 - slice_1 has been converted.
# Data for BF - 2011 - slice_2 has been converted.
# Data for BF - 2011 - slice_3 has been converted.
# Data for BF - 2011 - slice_4 has been converted.
# Data for BF - 2011 - slice_5 has been converted.
# Execution time: 7.8863 seconds
# Data for BF - 2011 has been converted to Stata in 1627.85 seconds.
# BF - 2012...
# Data for BF - 2012 - slice_1 has been converted.
# Data for BF - 2012 - slice_2 has been converted.
# Data for BF - 2012 - slice_3 has been converted.
# Data for BF - 2012 - slice_4 has been converted.
# Data for BF - 2012 - slice_5 has been converted.
# Execution time: 9.2906 seconds
# Data for BF - 2012 has been converted to Stata in 1637.14 seconds.
# BF - 2013...
# Data for BF - 2013 - slice_1 has been converted.
# Data for BF - 2013 - slice_2 has been converted.
# Data for BF - 2013 - slice_3 has been converted.
# Data for BF - 2013 - slice_4 has been converted.
# Data for BF - 2013 - slice_5 has been converted.
# Execution time: 9.8671 seconds
# Data for BF - 2013 has been converted to Stata in 1647.00 seconds.
# BF - 2014...
# Data for BF - 2014 - slice_1 has been converted.
# Data for BF - 2014 - slice_2 has been converted.
# Data for BF - 2014 - slice_3 has been converted.
# Data for BF - 2014 - slice_4 has been converted.
# Data for BF - 2014 - slice_5 has been converted.
# Execution time: 10.8254 seconds
# Data for BF - 2014 has been converted to Stata in 1657.83 seconds.
# BF - 2015...
# Data for BF - 2015 - slice_1 has been converted.
# Data for BF - 2015 - slice_2 has been converted.
# Data for BF - 2015 - slice_3 has been converted.
# Data for BF - 2015 - slice_4 has been converted.
# Data for BF - 2015 - slice_5 has been converted.
# Execution time: 12.4506 seconds
# Data for BF - 2015 has been converted to Stata in 1670.28 seconds.
# BF - 2016...
# Data for BF - 2016 - slice_1 has been converted.
# Data for BF - 2016 - slice_2 has been converted.
# Data for BF - 2016 - slice_3 has been converted.
# Data for BF - 2016 - slice_4 has been converted.
# Data for BF - 2016 - slice_5 has been converted.
# Execution time: 14.0729 seconds
# Data for BF - 2016 has been converted to Stata in 1684.35 seconds.
# BF - 2017...
# Data for BF - 2017 - slice_1 has been converted.
# Data for BF - 2017 - slice_2 has been converted.
# Data for BF - 2017 - slice_3 has been converted.
# Data for BF - 2017 - slice_4 has been converted.
# Data for BF - 2017 - slice_5 has been converted.
# Execution time: 16.7038 seconds
# Data for BF - 2017 has been converted to Stata in 1701.06 seconds.
# BF - 2018...
# Data for BF - 2018 - slice_1 has been converted.
# Data for BF - 2018 - slice_2 has been converted.
# Data for BF - 2018 - slice_3 has been converted.
# Data for BF - 2018 - slice_4 has been converted.
# Data for BF - 2018 - slice_5 has been converted.
# Execution time: 20.1152 seconds
# Data for BF - 2018 has been converted to Stata in 1721.17 seconds.
# BF - 2019...
# Data for BF - 2019 - slice_1 has been converted.
# Data for BF - 2019 - slice_2 has been converted.
# Data for BF - 2019 - slice_3 has been converted.
# Data for BF - 2019 - slice_4 has been converted.
# Data for BF - 2019 - slice_5 has been converted.
# Execution time: 22.5333 seconds
# Data for BF - 2019 has been converted to Stata in 1743.70 seconds.
# BF - 2020...
# Data for BF - 2020 - slice_1 has been converted.
# Data for BF - 2020 - slice_2 has been converted.
# Data for BF - 2020 - slice_3 has been converted.
# Data for BF - 2020 - slice_4 has been converted.
# Data for BF - 2020 - slice_5 has been converted.
# Execution time: 23.3267 seconds
# Data for BF - 2020 has been converted to Stata in 1767.03 seconds.
# BF - 2021...
# Data for BF - 2021 - slice_1 has been converted.
# Data for BF - 2021 - slice_2 has been converted.
# Data for BF - 2021 - slice_3 has been converted.
# Data for BF - 2021 - slice_4 has been converted.
# Data for BF - 2021 - slice_5 has been converted.
# Execution time: 24.7645 seconds
# Data for BF - 2021 has been converted to Stata in 1791.80 seconds.
# BF - 2022...
# Data for BF - 2022 - slice_1 has been converted.
# Data for BF - 2022 - slice_2 has been converted.
# Data for BF - 2022 - slice_3 has been converted.
# Data for BF - 2022 - slice_4 has been converted.
# Data for BF - 2022 - slice_5 has been converted.
# Execution time: 25.3795 seconds
# Data for BF - 2022 has been converted to Stata in 1817.18 seconds.
# BI - 2007...
# Data for BI - 2007 - slice_1 has been converted.
# Data for BI - 2007 - slice_2 has been converted.
# Data for BI - 2007 - slice_3 has been converted.
# Data for BI - 2007 - slice_4 has been converted.
# Data for BI - 2007 - slice_5 has been converted.
# Execution time: 5.4896 seconds
# Data for BI - 2007 has been converted to Stata in 1822.66 seconds.
# BI - 2008...
# Data for BI - 2008 - slice_1 has been converted.
# Data for BI - 2008 - slice_2 has been converted.
# Data for BI - 2008 - slice_3 has been converted.
# Data for BI - 2008 - slice_4 has been converted.
# Data for BI - 2008 - slice_5 has been converted.
# Execution time: 5.7480 seconds
# Data for BI - 2008 has been converted to Stata in 1828.41 seconds.
# BI - 2009...
# Data for BI - 2009 - slice_1 has been converted.
# Data for BI - 2009 - slice_2 has been converted.
# Data for BI - 2009 - slice_3 has been converted.
# Data for BI - 2009 - slice_4 has been converted.
# Data for BI - 2009 - slice_5 has been converted.
# Execution time: 6.6068 seconds
# Data for BI - 2009 has been converted to Stata in 1835.02 seconds.
# BI - 2010...
# Data for BI - 2010 - slice_1 has been converted.
# Data for BI - 2010 - slice_2 has been converted.
# Data for BI - 2010 - slice_3 has been converted.
# Data for BI - 2010 - slice_4 has been converted.
# Data for BI - 2010 - slice_5 has been converted.
# Execution time: 7.2206 seconds
# Data for BI - 2010 has been converted to Stata in 1842.24 seconds.
# BI - 2011...
# Data for BI - 2011 - slice_1 has been converted.
# Data for BI - 2011 - slice_2 has been converted.
# Data for BI - 2011 - slice_3 has been converted.
# Data for BI - 2011 - slice_4 has been converted.
# Data for BI - 2011 - slice_5 has been converted.
# Execution time: 7.9515 seconds
# Data for BI - 2011 has been converted to Stata in 1850.19 seconds.
# BI - 2012...
# Data for BI - 2012 - slice_1 has been converted.
# Data for BI - 2012 - slice_2 has been converted.
# Data for BI - 2012 - slice_3 has been converted.
# Data for BI - 2012 - slice_4 has been converted.
# Data for BI - 2012 - slice_5 has been converted.
# Execution time: 9.5966 seconds
# Data for BI - 2012 has been converted to Stata in 1859.79 seconds.
# BI - 2013...
# Data for BI - 2013 - slice_1 has been converted.
# Data for BI - 2013 - slice_2 has been converted.
# Data for BI - 2013 - slice_3 has been converted.
# Data for BI - 2013 - slice_4 has been converted.
# Data for BI - 2013 - slice_5 has been converted.
# Execution time: 10.0870 seconds
# Data for BI - 2013 has been converted to Stata in 1869.88 seconds.
# BI - 2014...
# Data for BI - 2014 - slice_1 has been converted.
# Data for BI - 2014 - slice_2 has been converted.
# Data for BI - 2014 - slice_3 has been converted.
# Data for BI - 2014 - slice_4 has been converted.
# Data for BI - 2014 - slice_5 has been converted.
# Execution time: 10.7115 seconds
# Data for BI - 2014 has been converted to Stata in 1880.59 seconds.
# BI - 2015...
# Data for BI - 2015 - slice_1 has been converted.
# Data for BI - 2015 - slice_2 has been converted.
# Data for BI - 2015 - slice_3 has been converted.
# Data for BI - 2015 - slice_4 has been converted.
# Data for BI - 2015 - slice_5 has been converted.
# Execution time: 12.5176 seconds
# Data for BI - 2015 has been converted to Stata in 1893.10 seconds.
# BI - 2016...
# Data for BI - 2016 - slice_1 has been converted.
# Data for BI - 2016 - slice_2 has been converted.
# Data for BI - 2016 - slice_3 has been converted.
# Data for BI - 2016 - slice_4 has been converted.
# Data for BI - 2016 - slice_5 has been converted.
# Execution time: 14.3698 seconds
# Data for BI - 2016 has been converted to Stata in 1907.47 seconds.
# BI - 2017...
# Data for BI - 2017 - slice_1 has been converted.
# Data for BI - 2017 - slice_2 has been converted.
# Data for BI - 2017 - slice_3 has been converted.
# Data for BI - 2017 - slice_4 has been converted.
# Data for BI - 2017 - slice_5 has been converted.
# Execution time: 16.9656 seconds
# Data for BI - 2017 has been converted to Stata in 1924.44 seconds.
# BI - 2018...
# Data for BI - 2018 - slice_1 has been converted.
# Data for BI - 2018 - slice_2 has been converted.
# Data for BI - 2018 - slice_3 has been converted.
# Data for BI - 2018 - slice_4 has been converted.
# Data for BI - 2018 - slice_5 has been converted.
# Execution time: 19.6321 seconds
# Data for BI - 2018 has been converted to Stata in 1944.07 seconds.
# BI - 2019...
# Data for BI - 2019 - slice_1 has been converted.
# Data for BI - 2019 - slice_2 has been converted.
# Data for BI - 2019 - slice_3 has been converted.
# Data for BI - 2019 - slice_4 has been converted.
# Data for BI - 2019 - slice_5 has been converted.
# Execution time: 22.9567 seconds
# Data for BI - 2019 has been converted to Stata in 1967.03 seconds.
# BI - 2020...
# Data for BI - 2020 - slice_1 has been converted.
# Data for BI - 2020 - slice_2 has been converted.
# Data for BI - 2020 - slice_3 has been converted.
# Data for BI - 2020 - slice_4 has been converted.
# Data for BI - 2020 - slice_5 has been converted.
# Execution time: 23.0330 seconds
# Data for BI - 2020 has been converted to Stata in 1990.06 seconds.
# BI - 2021...
# Data for BI - 2021 - slice_1 has been converted.
# Data for BI - 2021 - slice_2 has been converted.
# Data for BI - 2021 - slice_3 has been converted.
# Data for BI - 2021 - slice_4 has been converted.
# Data for BI - 2021 - slice_5 has been converted.
# Execution time: 24.3193 seconds
# Data for BI - 2021 has been converted to Stata in 2014.38 seconds.
# BI - 2022...
# Data for BI - 2022 - slice_1 has been converted.
# Data for BI - 2022 - slice_2 has been converted.
# Data for BI - 2022 - slice_3 has been converted.
# Data for BI - 2022 - slice_4 has been converted.
# Data for BI - 2022 - slice_5 has been converted.
# Execution time: 24.6236 seconds
# Data for BI - 2022 has been converted to Stata in 2039.00 seconds.
# CV - 2007...
# Data for CV - 2007 - slice_1 has been converted.
# Data for CV - 2007 - slice_2 has been converted.
# Data for CV - 2007 - slice_3 has been converted.
# Data for CV - 2007 - slice_4 has been converted.
# Data for CV - 2007 - slice_5 has been converted.
# Execution time: 5.3579 seconds
# Data for CV - 2007 has been converted to Stata in 2044.36 seconds.
# CV - 2008...
# Data for CV - 2008 - slice_1 has been converted.
# Data for CV - 2008 - slice_2 has been converted.
# Data for CV - 2008 - slice_3 has been converted.
# Data for CV - 2008 - slice_4 has been converted.
# Data for CV - 2008 - slice_5 has been converted.
# Execution time: 5.6276 seconds
# Data for CV - 2008 has been converted to Stata in 2049.99 seconds.
# CV - 2009...
# Data for CV - 2009 - slice_1 has been converted.
# Data for CV - 2009 - slice_2 has been converted.
# Data for CV - 2009 - slice_3 has been converted.
# Data for CV - 2009 - slice_4 has been converted.
# Data for CV - 2009 - slice_5 has been converted.
# Execution time: 6.3314 seconds
# Data for CV - 2009 has been converted to Stata in 2056.32 seconds.
# CV - 2010...
# Data for CV - 2010 - slice_1 has been converted.
# Data for CV - 2010 - slice_2 has been converted.
# Data for CV - 2010 - slice_3 has been converted.
# Data for CV - 2010 - slice_4 has been converted.
# Data for CV - 2010 - slice_5 has been converted.
# Execution time: 7.4810 seconds
# Data for CV - 2010 has been converted to Stata in 2063.80 seconds.
# CV - 2011...
# Data for CV - 2011 - slice_1 has been converted.
# Data for CV - 2011 - slice_2 has been converted.
# Data for CV - 2011 - slice_3 has been converted.
# Data for CV - 2011 - slice_4 has been converted.
# Data for CV - 2011 - slice_5 has been converted.
# Execution time: 8.3788 seconds
# Data for CV - 2011 has been converted to Stata in 2072.18 seconds.
# CV - 2012...
# Data for CV - 2012 - slice_1 has been converted.
# Data for CV - 2012 - slice_2 has been converted.
# Data for CV - 2012 - slice_3 has been converted.
# Data for CV - 2012 - slice_4 has been converted.
# Data for CV - 2012 - slice_5 has been converted.
# Execution time: 9.1815 seconds
# Data for CV - 2012 has been converted to Stata in 2081.36 seconds.
# CV - 2013...
# Data for CV - 2013 - slice_1 has been converted.
# Data for CV - 2013 - slice_2 has been converted.
# Data for CV - 2013 - slice_3 has been converted.
# Data for CV - 2013 - slice_4 has been converted.
# Data for CV - 2013 - slice_5 has been converted.
# Execution time: 10.0432 seconds
# Data for CV - 2013 has been converted to Stata in 2091.41 seconds.
# CV - 2014...
# Data for CV - 2014 - slice_1 has been converted.
# Data for CV - 2014 - slice_2 has been converted.
# Data for CV - 2014 - slice_3 has been converted.
# Data for CV - 2014 - slice_4 has been converted.
# Data for CV - 2014 - slice_5 has been converted.
# Execution time: 11.3261 seconds
# Data for CV - 2014 has been converted to Stata in 2102.73 seconds.
# CV - 2015...
# Data for CV - 2015 - slice_1 has been converted.
# Data for CV - 2015 - slice_2 has been converted.
# Data for CV - 2015 - slice_3 has been converted.
# Data for CV - 2015 - slice_4 has been converted.
# Data for CV - 2015 - slice_5 has been converted.
# Execution time: 12.9670 seconds
# Data for CV - 2015 has been converted to Stata in 2115.70 seconds.
# CV - 2016...
# Data for CV - 2016 - slice_1 has been converted.
# Data for CV - 2016 - slice_2 has been converted.
# Data for CV - 2016 - slice_3 has been converted.
# Data for CV - 2016 - slice_4 has been converted.
# Data for CV - 2016 - slice_5 has been converted.
# Execution time: 14.6770 seconds
# Data for CV - 2016 has been converted to Stata in 2130.38 seconds.
# CV - 2017...
# Data for CV - 2017 - slice_1 has been converted.
# Data for CV - 2017 - slice_2 has been converted.
# Data for CV - 2017 - slice_3 has been converted.
# Data for CV - 2017 - slice_4 has been converted.
# Data for CV - 2017 - slice_5 has been converted.
# Execution time: 17.0969 seconds
# Data for CV - 2017 has been converted to Stata in 2147.47 seconds.
# CV - 2018...
# Data for CV - 2018 - slice_1 has been converted.
# Data for CV - 2018 - slice_2 has been converted.
# Data for CV - 2018 - slice_3 has been converted.
# Data for CV - 2018 - slice_4 has been converted.
# Data for CV - 2018 - slice_5 has been converted.
# Execution time: 21.0191 seconds
# Data for CV - 2018 has been converted to Stata in 2168.49 seconds.
# CV - 2019...
# Data for CV - 2019 - slice_1 has been converted.
# Data for CV - 2019 - slice_2 has been converted.
# Data for CV - 2019 - slice_3 has been converted.
# Data for CV - 2019 - slice_4 has been converted.
# Data for CV - 2019 - slice_5 has been converted.
# Execution time: 23.3521 seconds
# Data for CV - 2019 has been converted to Stata in 2191.84 seconds.
# CV - 2020...
# Data for CV - 2020 - slice_1 has been converted.
# Data for CV - 2020 - slice_2 has been converted.
# Data for CV - 2020 - slice_3 has been converted.
# Data for CV - 2020 - slice_4 has been converted.
# Data for CV - 2020 - slice_5 has been converted.
# Execution time: 24.4917 seconds
# Data for CV - 2020 has been converted to Stata in 2216.34 seconds.
# CV - 2021...
# Data for CV - 2021 - slice_1 has been converted.
# Data for CV - 2021 - slice_2 has been converted.
# Data for CV - 2021 - slice_3 has been converted.
# Data for CV - 2021 - slice_4 has been converted.
# Data for CV - 2021 - slice_5 has been converted.
# Execution time: 25.8686 seconds
# Data for CV - 2021 has been converted to Stata in 2242.21 seconds.
# CV - 2022...
# Data for CV - 2022 - slice_1 has been converted.
# Data for CV - 2022 - slice_2 has been converted.
# Data for CV - 2022 - slice_3 has been converted.
# Data for CV - 2022 - slice_4 has been converted.
# Data for CV - 2022 - slice_5 has been converted.
# Execution time: 26.4454 seconds
# Data for CV - 2022 has been converted to Stata in 2268.65 seconds.
# CM - 2007...
# Data for CM - 2007 - slice_1 has been converted.
# Data for CM - 2007 - slice_2 has been converted.
# Data for CM - 2007 - slice_3 has been converted.
# Data for CM - 2007 - slice_4 has been converted.
# Data for CM - 2007 - slice_5 has been converted.
# Execution time: 5.8562 seconds
# Data for CM - 2007 has been converted to Stata in 2274.51 seconds.
# CM - 2008...
# Data for CM - 2008 - slice_1 has been converted.
# Data for CM - 2008 - slice_2 has been converted.
# Data for CM - 2008 - slice_3 has been converted.
# Data for CM - 2008 - slice_4 has been converted.
# Data for CM - 2008 - slice_5 has been converted.
# Execution time: 6.4313 seconds
# Data for CM - 2008 has been converted to Stata in 2280.94 seconds.
# CM - 2009...
# Data for CM - 2009 - slice_1 has been converted.
# Data for CM - 2009 - slice_2 has been converted.
# Data for CM - 2009 - slice_3 has been converted.
# Data for CM - 2009 - slice_4 has been converted.
# Data for CM - 2009 - slice_5 has been converted.
# Execution time: 7.0738 seconds
# Data for CM - 2009 has been converted to Stata in 2288.01 seconds.
# CM - 2010...
# Data for CM - 2010 - slice_1 has been converted.
# Data for CM - 2010 - slice_2 has been converted.
# Data for CM - 2010 - slice_3 has been converted.
# Data for CM - 2010 - slice_4 has been converted.
# Data for CM - 2010 - slice_5 has been converted.
# Execution time: 8.2460 seconds
# Data for CM - 2010 has been converted to Stata in 2296.26 seconds.
# CM - 2011...
# Data for CM - 2011 - slice_1 has been converted.
# Data for CM - 2011 - slice_2 has been converted.
# Data for CM - 2011 - slice_3 has been converted.
# Data for CM - 2011 - slice_4 has been converted.
# Data for CM - 2011 - slice_5 has been converted.
# Execution time: 9.5949 seconds
# Data for CM - 2011 has been converted to Stata in 2305.85 seconds.
# CM - 2012...
# Data for CM - 2012 - slice_1 has been converted.
# Data for CM - 2012 - slice_2 has been converted.
# Data for CM - 2012 - slice_3 has been converted.
# Data for CM - 2012 - slice_4 has been converted.
# Data for CM - 2012 - slice_5 has been converted.
# Execution time: 10.9802 seconds
# Data for CM - 2012 has been converted to Stata in 2316.83 seconds.
# CM - 2013...
# Data for CM - 2013 - slice_1 has been converted.
# Data for CM - 2013 - slice_2 has been converted.
# Data for CM - 2013 - slice_3 has been converted.
# Data for CM - 2013 - slice_4 has been converted.
# Data for CM - 2013 - slice_5 has been converted.
# ...
# Data for VE - 2010 - slice_4 has been converted.
# Data for VE - 2010 - slice_5 has been converted.
# Execution time: 11.7348 seconds
# Data for VE - 2010 has been converted to Stata in 94034.99 seconds.
# VE - 2011...
# Data for VE - 2011 - slice_1 has been converted.
# Data for VE - 2011 - slice_2 has been converted.
# Data for VE - 2011 - slice_3 has been converted.
# Data for VE - 2011 - slice_4 has been converted.
# Data for VE - 2011 - slice_5 has been converted.
# Execution time: 12.2156 seconds
# Data for VE - 2011 has been converted to Stata in 94047.21 seconds.
# VE - 2012...
# Data for VE - 2012 - slice_1 has been converted.
# Data for VE - 2012 - slice_2 has been converted.
# Data for VE - 2012 - slice_3 has been converted.
# Data for VE - 2012 - slice_4 has been converted.
# Data for VE - 2012 - slice_5 has been converted.
# Execution time: 13.8447 seconds
# Data for VE - 2012 has been converted to Stata in 94061.05 seconds.
# VE - 2013...
# Data for VE - 2013 - slice_1 has been converted.
# Data for VE - 2013 - slice_2 has been converted.
# Data for VE - 2013 - slice_3 has been converted.
# Data for VE - 2013 - slice_4 has been converted.
# Data for VE - 2013 - slice_5 has been converted.
# Execution time: 14.8857 seconds
# Data for VE - 2013 has been converted to Stata in 94075.94 seconds.
# VE - 2014...
# Data for VE - 2014 - slice_1 has been converted.
# Data for VE - 2014 - slice_2 has been converted.
# Data for VE - 2014 - slice_3 has been converted.
# Data for VE - 2014 - slice_4 has been converted.
# Data for VE - 2014 - slice_5 has been converted.
# Execution time: 15.7550 seconds
# Data for VE - 2014 has been converted to Stata in 94091.69 seconds.
# VE - 2015...
# Data for VE - 2015 - slice_1 has been converted.
# Data for VE - 2015 - slice_2 has been converted.
# Data for VE - 2015 - slice_3 has been converted.
# Data for VE - 2015 - slice_4 has been converted.
# Data for VE - 2015 - slice_5 has been converted.
# Execution time: 19.2006 seconds
# Data for VE - 2015 has been converted to Stata in 94110.89 seconds.
# VE - 2016...
# Data for VE - 2016 - slice_1 has been converted.
# Data for VE - 2016 - slice_2 has been converted.
# Data for VE - 2016 - slice_3 has been converted.
# Data for VE - 2016 - slice_4 has been converted.
# Data for VE - 2016 - slice_5 has been converted.
# Execution time: 22.1134 seconds
# Data for VE - 2016 has been converted to Stata in 94133.00 seconds.
# VE - 2017...
# Data for VE - 2017 - slice_1 has been converted.
# Data for VE - 2017 - slice_2 has been converted.
# Data for VE - 2017 - slice_3 has been converted.
# Data for VE - 2017 - slice_4 has been converted.
# Data for VE - 2017 - slice_5 has been converted.
# Execution time: 27.4983 seconds
# Data for VE - 2017 has been converted to Stata in 94160.50 seconds.
# VE - 2018...
# Data for VE - 2018 - slice_1 has been converted.
# Data for VE - 2018 - slice_2 has been converted.
# Data for VE - 2018 - slice_3 has been converted.
# Data for VE - 2018 - slice_4 has been converted.
# Data for VE - 2018 - slice_5 has been converted.
# Execution time: 29.7494 seconds
# Data for VE - 2018 has been converted to Stata in 94190.25 seconds.
# VE - 2019...
# Data for VE - 2019 - slice_1 has been converted.
# Data for VE - 2019 - slice_2 has been converted.
# Data for VE - 2019 - slice_3 has been converted.
# Data for VE - 2019 - slice_4 has been converted.
# Data for VE - 2019 - slice_5 has been converted.
# Execution time: 33.7773 seconds
# Data for VE - 2019 has been converted to Stata in 94224.03 seconds.
# VE - 2020...
# Data for VE - 2020 - slice_1 has been converted.
# Data for VE - 2020 - slice_2 has been converted.
# Data for VE - 2020 - slice_3 has been converted.
# Data for VE - 2020 - slice_4 has been converted.
# Data for VE - 2020 - slice_5 has been converted.
# Execution time: 34.3731 seconds
# Data for VE - 2020 has been converted to Stata in 94258.40 seconds.
# VE - 2021...
# Data for VE - 2021 - slice_1 has been converted.
# Data for VE - 2021 - slice_2 has been converted.
# Data for VE - 2021 - slice_3 has been converted.
# Data for VE - 2021 - slice_4 has been converted.
# Data for VE - 2021 - slice_5 has been converted.
# Execution time: 37.8171 seconds
# Data for VE - 2021 has been converted to Stata in 94296.22 seconds.
# VE - 2022...
# Data for VE - 2022 - slice_1 has been converted.
# Data for VE - 2022 - slice_2 has been converted.
# Data for VE - 2022 - slice_3 has been converted.
# Data for VE - 2022 - slice_4 has been converted.
# Data for VE - 2022 - slice_5 has been converted.
# Execution time: 36.9003 seconds
# Data for VE - 2022 has been converted to Stata in 94333.12 seconds.
# VG - 2007...
# Data for VG - 2007 - slice_1 has been converted.
# Data for VG - 2007 - slice_2 has been converted.
# Data for VG - 2007 - slice_3 has been converted.
# Data for VG - 2007 - slice_4 has been converted.
# Data for VG - 2007 - slice_5 has been converted.
# Execution time: 9.8879 seconds
# Data for VG - 2007 has been converted to Stata in 94343.01 seconds.
# VG - 2008...
# Data for VG - 2008 - slice_1 has been converted.
# Data for VG - 2008 - slice_2 has been converted.
# Data for VG - 2008 - slice_3 has been converted.
# Data for VG - 2008 - slice_4 has been converted.
# Data for VG - 2008 - slice_5 has been converted.
# Execution time: 10.6394 seconds
# Data for VG - 2008 has been converted to Stata in 94353.65 seconds.
# VG - 2009...
# Data for VG - 2009 - slice_1 has been converted.
# Data for VG - 2009 - slice_2 has been converted.
# Data for VG - 2009 - slice_3 has been converted.
# Data for VG - 2009 - slice_4 has been converted.
# Data for VG - 2009 - slice_5 has been converted.
# Execution time: 11.5581 seconds
# Data for VG - 2009 has been converted to Stata in 94365.21 seconds.
# VG - 2010...
# Data for VG - 2010 - slice_1 has been converted.
# Data for VG - 2010 - slice_2 has been converted.
# Data for VG - 2010 - slice_3 has been converted.
# Data for VG - 2010 - slice_4 has been converted.
# Data for VG - 2010 - slice_5 has been converted.
# Execution time: 12.6585 seconds
# Data for VG - 2010 has been converted to Stata in 94377.87 seconds.
# VG - 2011...
# Data for VG - 2011 - slice_1 has been converted.
# Data for VG - 2011 - slice_2 has been converted.
# Data for VG - 2011 - slice_3 has been converted.
# Data for VG - 2011 - slice_4 has been converted.
# Data for VG - 2011 - slice_5 has been converted.
# Execution time: 14.7163 seconds
# Data for VG - 2011 has been converted to Stata in 94392.58 seconds.
# VG - 2012...
# Data for VG - 2012 - slice_1 has been converted.
# Data for VG - 2012 - slice_2 has been converted.
# Data for VG - 2012 - slice_3 has been converted.
# Data for VG - 2012 - slice_4 has been converted.
# Data for VG - 2012 - slice_5 has been converted.
# Execution time: 17.7955 seconds
# Data for VG - 2012 has been converted to Stata in 94410.38 seconds.
# VG - 2013...
# Data for VG - 2013 - slice_1 has been converted.
# Data for VG - 2013 - slice_2 has been converted.
# Data for VG - 2013 - slice_3 has been converted.
# Data for VG - 2013 - slice_4 has been converted.
# Data for VG - 2013 - slice_5 has been converted.
# Execution time: 19.4566 seconds
# Data for VG - 2013 has been converted to Stata in 94429.83 seconds.
# VG - 2014...
# Data for VG - 2014 - slice_1 has been converted.
# Data for VG - 2014 - slice_2 has been converted.
# Data for VG - 2014 - slice_3 has been converted.
# Data for VG - 2014 - slice_4 has been converted.
# Data for VG - 2014 - slice_5 has been converted.
# Execution time: 18.8965 seconds
# Data for VG - 2014 has been converted to Stata in 94448.73 seconds.
# VG - 2015...
# Data for VG - 2015 - slice_1 has been converted.
# Data for VG - 2015 - slice_2 has been converted.
# Data for VG - 2015 - slice_3 has been converted.
# Data for VG - 2015 - slice_4 has been converted.
# Data for VG - 2015 - slice_5 has been converted.
# Execution time: 23.0667 seconds
# Data for VG - 2015 has been converted to Stata in 94471.80 seconds.
# VG - 2016...
# Data for VG - 2016 - slice_1 has been converted.
# Data for VG - 2016 - slice_2 has been converted.
# Data for VG - 2016 - slice_3 has been converted.
# Data for VG - 2016 - slice_4 has been converted.
# Data for VG - 2016 - slice_5 has been converted.
# Execution time: 26.2950 seconds
# Data for VG - 2016 has been converted to Stata in 94498.09 seconds.
# VG - 2017...
# Data for VG - 2017 - slice_1 has been converted.
# Data for VG - 2017 - slice_2 has been converted.
# Data for VG - 2017 - slice_3 has been converted.
# Data for VG - 2017 - slice_4 has been converted.
# Data for VG - 2017 - slice_5 has been converted.
# Execution time: 30.7327 seconds
# Data for VG - 2017 has been converted to Stata in 94528.83 seconds.
# VG - 2018...
# Data for VG - 2018 - slice_1 has been converted.
# Data for VG - 2018 - slice_2 has been converted.
# Data for VG - 2018 - slice_3 has been converted.
# Data for VG - 2018 - slice_4 has been converted.
# Data for VG - 2018 - slice_5 has been converted.
# Execution time: 34.3647 seconds
# Data for VG - 2018 has been converted to Stata in 94563.19 seconds.
# VG - 2019...
# Data for VG - 2019 - slice_1 has been converted.
# Data for VG - 2019 - slice_2 has been converted.
# Data for VG - 2019 - slice_3 has been converted.
# Data for VG - 2019 - slice_4 has been converted.
# Data for VG - 2019 - slice_5 has been converted.
# Execution time: 39.9678 seconds
# Data for VG - 2019 has been converted to Stata in 94603.16 seconds.
# VG - 2020...
# Data for VG - 2020 - slice_1 has been converted.
# Data for VG - 2020 - slice_2 has been converted.
# Data for VG - 2020 - slice_3 has been converted.
# Data for VG - 2020 - slice_4 has been converted.
# Data for VG - 2020 - slice_5 has been converted.
# Execution time: 41.6255 seconds
# Data for VG - 2020 has been converted to Stata in 94644.79 seconds.
# VG - 2021...
# Data for VG - 2021 - slice_1 has been converted.
# Data for VG - 2021 - slice_2 has been converted.
# Data for VG - 2021 - slice_3 has been converted.
# Data for VG - 2021 - slice_4 has been converted.
# Data for VG - 2021 - slice_5 has been converted.
# Execution time: 43.3803 seconds
# Data for VG - 2021 has been converted to Stata in 94688.17 seconds.
# VG - 2022...
# Data for VG - 2022 - slice_1 has been converted.
# Data for VG - 2022 - slice_2 has been converted.
# Data for VG - 2022 - slice_3 has been converted.
# Data for VG - 2022 - slice_4 has been converted.
# Data for VG - 2022 - slice_5 has been converted.
# Execution time: 43.6723 seconds
# Data for VG - 2022 has been converted to Stata in 94731.84 seconds.
# VI - 2007...
# Data for VI - 2007 - slice_1 has been converted.
# Data for VI - 2007 - slice_2 has been converted.
# Data for VI - 2007 - slice_3 has been converted.
# Data for VI - 2007 - slice_4 has been converted.
# Data for VI - 2007 - slice_5 has been converted.
# Execution time: 5.1046 seconds
# Data for VI - 2007 has been converted to Stata in 94736.94 seconds.
# VI - 2008...
# Data for VI - 2008 - slice_1 has been converted.
# Data for VI - 2008 - slice_2 has been converted.
# Data for VI - 2008 - slice_3 has been converted.
# Data for VI - 2008 - slice_4 has been converted.
# Data for VI - 2008 - slice_5 has been converted.
# Execution time: 5.6219 seconds
# Data for VI - 2008 has been converted to Stata in 94742.57 seconds.
# VI - 2009...
# Data for VI - 2009 - slice_1 has been converted.
# Data for VI - 2009 - slice_2 has been converted.
# Data for VI - 2009 - slice_3 has been converted.
# Data for VI - 2009 - slice_4 has been converted.
# Data for VI - 2009 - slice_5 has been converted.
# Execution time: 5.9228 seconds
# Data for VI - 2009 has been converted to Stata in 94748.49 seconds.
# VI - 2010...
# Data for VI - 2010 - slice_1 has been converted.
# Data for VI - 2010 - slice_2 has been converted.
# Data for VI - 2010 - slice_3 has been converted.
# Data for VI - 2010 - slice_4 has been converted.
# Data for VI - 2010 - slice_5 has been converted.
# Execution time: 6.5914 seconds
# Data for VI - 2010 has been converted to Stata in 94755.08 seconds.
# VI - 2011...
# Data for VI - 2011 - slice_1 has been converted.
# Data for VI - 2011 - slice_2 has been converted.
# Data for VI - 2011 - slice_3 has been converted.
# Data for VI - 2011 - slice_4 has been converted.
# Data for VI - 2011 - slice_5 has been converted.
# Execution time: 8.1461 seconds
# Data for VI - 2011 has been converted to Stata in 94763.23 seconds.
# VI - 2012...
# Data for VI - 2012 - slice_1 has been converted.
# Data for VI - 2012 - slice_2 has been converted.
# Data for VI - 2012 - slice_3 has been converted.
# Data for VI - 2012 - slice_4 has been converted.
# Data for VI - 2012 - slice_5 has been converted.
# Execution time: 8.8857 seconds
# Data for VI - 2012 has been converted to Stata in 94772.11 seconds.
# VI - 2013...
# Data for VI - 2013 - slice_1 has been converted.
# Data for VI - 2013 - slice_2 has been converted.
# Data for VI - 2013 - slice_3 has been converted.
# Data for VI - 2013 - slice_4 has been converted.
# Data for VI - 2013 - slice_5 has been converted.
# Execution time: 11.4068 seconds
# Data for VI - 2013 has been converted to Stata in 94783.52 seconds.
# VI - 2014...
# Data for VI - 2014 - slice_1 has been converted.
# Data for VI - 2014 - slice_2 has been converted.
# Data for VI - 2014 - slice_3 has been converted.
# Data for VI - 2014 - slice_4 has been converted.
# Data for VI - 2014 - slice_5 has been converted.
# Execution time: 10.8057 seconds
# Data for VI - 2014 has been converted to Stata in 94794.32 seconds.
# VI - 2015...
# Data for VI - 2015 - slice_1 has been converted.
# Data for VI - 2015 - slice_2 has been converted.
# Data for VI - 2015 - slice_3 has been converted.
# Data for VI - 2015 - slice_4 has been converted.
# Data for VI - 2015 - slice_5 has been converted.
# Execution time: 12.2002 seconds
# Data for VI - 2015 has been converted to Stata in 94806.52 seconds.
# VI - 2016...
# Data for VI - 2016 - slice_1 has been converted.
# Data for VI - 2016 - slice_2 has been converted.
# Data for VI - 2016 - slice_3 has been converted.
# Data for VI - 2016 - slice_4 has been converted.
# Data for VI - 2016 - slice_5 has been converted.
# Execution time: 13.6627 seconds
# Data for VI - 2016 has been converted to Stata in 94820.19 seconds.
# VI - 2017...
# Data for VI - 2017 - slice_1 has been converted.
# Data for VI - 2017 - slice_2 has been converted.
# Data for VI - 2017 - slice_3 has been converted.
# Data for VI - 2017 - slice_4 has been converted.
# Data for VI - 2017 - slice_5 has been converted.
# Execution time: 15.3840 seconds
# Data for VI - 2017 has been converted to Stata in 94835.57 seconds.
# VI - 2018...
# Data for VI - 2018 - slice_1 has been converted.
# Data for VI - 2018 - slice_2 has been converted.
# Data for VI - 2018 - slice_3 has been converted.
# Data for VI - 2018 - slice_4 has been converted.
# Data for VI - 2018 - slice_5 has been converted.
# Execution time: 18.4411 seconds
# Data for VI - 2018 has been converted to Stata in 94854.01 seconds.
# VI - 2019...
# Data for VI - 2019 - slice_1 has been converted.
# Data for VI - 2019 - slice_2 has been converted.
# Data for VI - 2019 - slice_3 has been converted.
# Data for VI - 2019 - slice_4 has been converted.
# Data for VI - 2019 - slice_5 has been converted.
# Execution time: 21.3589 seconds
# Data for VI - 2019 has been converted to Stata in 94875.37 seconds.
# VI - 2020...
# Data for VI - 2020 - slice_1 has been converted.
# Data for VI - 2020 - slice_2 has been converted.
# Data for VI - 2020 - slice_3 has been converted.
# Data for VI - 2020 - slice_4 has been converted.
# Data for VI - 2020 - slice_5 has been converted.
# Execution time: 21.8439 seconds
# Data for VI - 2020 has been converted to Stata in 94897.22 seconds.
# VI - 2021...
# Data for VI - 2021 - slice_1 has been converted.
# Data for VI - 2021 - slice_2 has been converted.
# Data for VI - 2021 - slice_3 has been converted.
# Data for VI - 2021 - slice_4 has been converted.
# Data for VI - 2021 - slice_5 has been converted.
# Execution time: 22.7991 seconds
# Data for VI - 2021 has been converted to Stata in 94920.01 seconds.
# VI - 2022...
# Data for VI - 2022 - slice_1 has been converted.
# Data for VI - 2022 - slice_2 has been converted.
# Data for VI - 2022 - slice_3 has been converted.
# Data for VI - 2022 - slice_4 has been converted.
# Data for VI - 2022 - slice_5 has been converted.
# Execution time: 23.3472 seconds
# Data for VI - 2022 has been converted to Stata in 94943.36 seconds.
# Total execution time: 94944.18 seconds.

# %%
# open errors
import json 

with open("errors/errors_guos_world.json", "r") as f:
    errors = json.load(f)

errors
# Out:
# {}

# %% [markdown]
# ## Zip the files

# %%
ZIP_OUTPOUT = "..\\zipped_files\\guos_world"

data_processor.compress_csv_files(folder_to_zip=OUTPUT_PATH, zip_output=ZIP_OUTPOUT)
