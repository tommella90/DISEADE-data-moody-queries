# %% [markdown]
# # CONVERT FILES WITH DUCK_DB

# %%
import pandas as pd
import duckdb
import os
import time as pytime
import numpy as np
import psutil
import sys
import glob
import json
sys.path.insert(0, os.path.abspath(".."))
from utils import time, data_processor, constants
import gc

persistent_conn = duckdb.connect()

# %%
TEMP_TABLE_OWNERSHIP_HISTORY_GUO = "..\\data_processed\\ownership_history\\guos\\"
TEMP_TABLE_FIRMOGRAPHICS = "..\\data_processed\\firmographics_processed\\firmographics_full\\"
TEMP_TABLE_KEY_FINANCIALS = "..\\data_processed\\key_financials_detailed_processed\\"
OUTPUT_PATH = "..\\zipped_files\\guos_eu\\"
os.makedirs(OUTPUT_PATH, exist_ok=True)
eu27_countries = constants.eu
asia = constants.asia
africa = constants.africa
oceania = constants.oceania
americas = constants.americas
balkans = constants.balkans

all_countries = asia + africa + oceania + americas + balkans 
# eu_countries, balkans

# %%
def log_memory():
    mem = psutil.virtual_memory()
    print(f"[MEMORY] Used: {mem.percent}%, Available: {round(mem.available / (1024 ** 3), 2)} GB")

# %%
# drop 'IT' from eu27_countries
# eu27_countries.remove('IT')
# eu27_countries.append('DE')

# %%
''' DONE
- EU
- BALKANS
= asia
=americas
- africa
= oceania
'''
# Out:
# ' DONE\n- EU\n- BALKANS\n= asia\n'

# %%
for country in oceania:
    for year in range(2007, 2024):
        ownership_path = os.path.join(TEMP_TABLE_OWNERSHIP_HISTORY_GUO, f"{country}_{year}.parquet")
        firmo_path = os.path.join(TEMP_TABLE_FIRMOGRAPHICS, f"{country}.parquet")
        financials_path = os.path.join(TEMP_TABLE_KEY_FINANCIALS, f"key_financials_detailed_{country}.parquet")

        print(f"[INFO] Loading and joining data from:\n  - Ownership: {ownership_path}\n  - Firmographics: {firmo_path}")

        combined_query = f"""
        WITH
        firmographics_dedup AS (
            SELECT DISTINCT ON (bvd_id_number) *
            FROM parquet_scan('{firmo_path}')
        ),
        financials_dedup AS (
            SELECT DISTINCT ON (bvd_id_number) *
            FROM parquet_scan('{financials_path}')
        )
        SELECT o.*,
            f.nuts2,
            f.nace_rev_2_core_code_4_digits_,
            f.city_native_,
            f.type_of_entity,
            f.status,
            k.operating_revenue_turnover_,
            k.number_of_employees
        FROM parquet_scan('{ownership_path}') AS o
        LEFT JOIN firmographics_dedup AS f
        ON o.guo_25 = f.bvd_id_number
        LEFT JOIN financials_dedup AS k
        ON o.guo_25 = k.bvd_id_number
        WHERE o.type_of_relation = 'GUO 25'
        """

        # Execute query
        con = duckdb.connect()
        combined_df = con.execute(combined_query).fetchdf()
        # Output info
        print(f"[INFO] Combined rows (ownership only): {len(combined_df)}")
        print(f"[MEMORY] Used: {psutil.virtual_memory().percent}%, Available: {round(psutil.virtual_memory().available / 1e9, 2)} GB")

        final_path = os.path.join(OUTPUT_PATH, f"{country}_{year}.csv.gz")
        combined_df.to_csv(final_path, index=False, compression='gzip')
        print(f"Saved at {final_path}")
# Out:
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2007.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.51 GB
# Saved at ..\zipped_files\guos_eu\AS_2007.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2008.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.51 GB
# Saved at ..\zipped_files\guos_eu\AS_2008.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2009.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.51 GB
# Saved at ..\zipped_files\guos_eu\AS_2009.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2010.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.51 GB
# Saved at ..\zipped_files\guos_eu\AS_2010.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2011.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.51 GB
# Saved at ..\zipped_files\guos_eu\AS_2011.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2012.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.51 GB
# Saved at ..\zipped_files\guos_eu\AS_2012.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2013.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.51 GB
# Saved at ..\zipped_files\guos_eu\AS_2013.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2014.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.51 GB
# Saved at ..\zipped_files\guos_eu\AS_2014.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2015.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.51 GB
# Saved at ..\zipped_files\guos_eu\AS_2015.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2016.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.52 GB
# Saved at ..\zipped_files\guos_eu\AS_2016.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2017.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.52 GB
# Saved at ..\zipped_files\guos_eu\AS_2017.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2018.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.52 GB
# Saved at ..\zipped_files\guos_eu\AS_2018.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2019.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.51 GB
# Saved at ..\zipped_files\guos_eu\AS_2019.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2020.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.51 GB
# Saved at ..\zipped_files\guos_eu\AS_2020.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2021.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.51 GB
# Saved at ..\zipped_files\guos_eu\AS_2021.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2022.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.51 GB
# Saved at ..\zipped_files\guos_eu\AS_2022.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AS_2023.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AS.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 25.8%, Available: 119.51 GB
# Saved at ..\zipped_files\guos_eu\AS_2023.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2007.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 935973
# [MEMORY] Used: 25.7%, Available: 119.63 GB
# Saved at ..\zipped_files\guos_eu\AU_2007.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2008.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 1215829
# [MEMORY] Used: 26.1%, Available: 119.05 GB
# Saved at ..\zipped_files\guos_eu\AU_2008.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2009.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 1532996
# [MEMORY] Used: 22.9%, Available: 124.18 GB
# Saved at ..\zipped_files\guos_eu\AU_2009.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2010.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 2514730
# [MEMORY] Used: 17.0%, Available: 133.65 GB
# Saved at ..\zipped_files\guos_eu\AU_2010.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2011.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 4039407
# [MEMORY] Used: 16.7%, Available: 134.18 GB
# Saved at ..\zipped_files\guos_eu\AU_2011.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2012.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 6075812
# [MEMORY] Used: 17.4%, Available: 133.09 GB
# Saved at ..\zipped_files\guos_eu\AU_2012.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2013.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 7064489
# [MEMORY] Used: 17.0%, Available: 133.74 GB
# Saved at ..\zipped_files\guos_eu\AU_2013.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2014.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 7655382
# [MEMORY] Used: 17.1%, Available: 133.51 GB
# Saved at ..\zipped_files\guos_eu\AU_2014.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2015.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 8512153
# [MEMORY] Used: 17.1%, Available: 133.46 GB
# Saved at ..\zipped_files\guos_eu\AU_2015.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2016.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 9153030
# [MEMORY] Used: 17.3%, Available: 133.16 GB
# Saved at ..\zipped_files\guos_eu\AU_2016.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2017.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 10479610
# [MEMORY] Used: 17.4%, Available: 132.96 GB
# Saved at ..\zipped_files\guos_eu\AU_2017.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2018.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 8496616
# [MEMORY] Used: 17.2%, Available: 133.38 GB
# Saved at ..\zipped_files\guos_eu\AU_2018.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2019.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 9479780
# [MEMORY] Used: 17.2%, Available: 133.29 GB
# Saved at ..\zipped_files\guos_eu\AU_2019.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2020.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 9473079
# [MEMORY] Used: 17.3%, Available: 133.17 GB
# Saved at ..\zipped_files\guos_eu\AU_2020.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2021.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 10092869
# [MEMORY] Used: 17.3%, Available: 133.15 GB
# Saved at ..\zipped_files\guos_eu\AU_2021.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2022.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 10117705
# [MEMORY] Used: 17.4%, Available: 133.02 GB
# Saved at ..\zipped_files\guos_eu\AU_2022.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\AU_2023.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\AU.parquet
# [INFO] Combined rows (ownership only): 10621419
# [MEMORY] Used: 17.4%, Available: 133.02 GB
# Saved at ..\zipped_files\guos_eu\AU_2023.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2007.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2007.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2008.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2008.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2009.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2009.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2010.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2010.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2011.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2011.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2012.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2012.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2013.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2013.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2014.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2014.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2015.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2015.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2016.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2016.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2017.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2017.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2018.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2018.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2019.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2019.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2020.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2020.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2021.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2021.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2022.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2022.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CX_2023.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CX.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CX_2023.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2007.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2007.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2008.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2008.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2009.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2009.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2010.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2010.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2011.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2011.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2012.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2012.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2013.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2013.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2014.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2014.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2015.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2015.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2016.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2016.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2017.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2017.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2018.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2018.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2019.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2019.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2020.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2020.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2021.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2021.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2022.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2022.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CC_2023.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CC.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CC_2023.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2007.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2007.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2008.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2008.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2009.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2009.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2010.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2010.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2011.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2011.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2012.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2012.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2013.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2013.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2014.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2014.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2015.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2015.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2016.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2016.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2017.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2017.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2018.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2018.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2019.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2019.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2020.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2020.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2021.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2021.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2022.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2022.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\CK_2023.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\CK.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\CK_2023.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2007.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 127
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\FJ_2007.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2008.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 161
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\FJ_2008.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2009.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 202
# [MEMORY] Used: 15.8%, Available: 135.59 GB
# Saved at ..\zipped_files\guos_eu\FJ_2009.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2010.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 196
# [MEMORY] Used: 15.8%, Available: 135.59 GB
# Saved at ..\zipped_files\guos_eu\FJ_2010.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2011.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 211
# [MEMORY] Used: 15.8%, Available: 135.59 GB
# Saved at ..\zipped_files\guos_eu\FJ_2011.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2012.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 272
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\FJ_2012.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2013.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 270
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\FJ_2013.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2014.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 293
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\FJ_2014.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2015.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 280
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\FJ_2015.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2016.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 303
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\FJ_2016.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2017.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 302
# [MEMORY] Used: 15.8%, Available: 135.59 GB
# Saved at ..\zipped_files\guos_eu\FJ_2017.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2018.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 314
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\FJ_2018.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2019.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 328
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\FJ_2019.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2020.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 343
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\FJ_2020.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2021.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 353
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\FJ_2021.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2022.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 378
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\FJ_2022.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\FJ_2023.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\FJ.parquet
# [INFO] Combined rows (ownership only): 382
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\FJ_2023.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2007.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2007.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2008.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2008.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2009.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2009.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2010.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2010.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2011.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2011.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2012.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2012.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2013.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2013.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2014.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2014.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2015.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2015.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2016.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2016.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2017.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2017.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2018.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2018.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2019.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2019.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2020.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2020.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2021.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2021.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2022.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2022.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\PF_2023.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\PF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\PF_2023.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2007.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\GU_2007.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2008.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\GU_2008.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2009.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\GU_2009.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2010.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\GU_2010.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2011.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\GU_2011.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2012.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\GU_2012.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2013.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\GU_2013.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2014.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\GU_2014.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2015.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\GU_2015.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2016.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\GU_2016.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2017.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\GU_2017.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2018.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\GU_2018.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2019.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\GU_2019.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2020.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\GU_2020.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2021.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\GU_2021.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2022.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\GU_2022.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\GU_2023.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\GU.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\GU_2023.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\HM_2007.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\HM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\HM_2007.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\HM_2008.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\HM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\HM_2008.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\HM_2009.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\HM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\HM_2009.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\HM_2010.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\HM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\HM_2010.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\HM_2011.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\HM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\HM_2011.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\HM_2012.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\HM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\HM_2012.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\HM_2013.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\HM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\HM_2013.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\HM_2014.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\HM.parquet
# [INFO] Combined rows (ownership only): 0
# ...
#   - Ownership: ..\data_processed\ownership_history\guos\UM_2010.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\UM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\UM_2010.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\UM_2011.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\UM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\UM_2011.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\UM_2012.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\UM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\UM_2012.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\UM_2013.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\UM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\UM_2013.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\UM_2014.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\UM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\UM_2014.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\UM_2015.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\UM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\UM_2015.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\UM_2016.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\UM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\UM_2016.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\UM_2017.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\UM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\UM_2017.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\UM_2018.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\UM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\UM_2018.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\UM_2019.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\UM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\UM_2019.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\UM_2020.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\UM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\UM_2020.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\UM_2021.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\UM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\UM_2021.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\UM_2022.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\UM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\UM_2022.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\UM_2023.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\UM.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\UM_2023.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2007.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 113
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\VU_2007.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2008.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 119
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\VU_2008.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2009.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 169
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\VU_2009.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2010.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 185
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\VU_2010.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2011.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 179
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\VU_2011.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2012.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 211
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\VU_2012.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2013.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 240
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\VU_2013.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2014.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 234
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\VU_2014.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2015.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 241
# [MEMORY] Used: 15.8%, Available: 135.58 GB
# Saved at ..\zipped_files\guos_eu\VU_2015.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2016.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 243
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\VU_2016.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2017.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 268
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\VU_2017.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2018.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 254
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\VU_2018.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2019.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 256
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\VU_2019.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2020.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 272
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\VU_2020.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2021.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 279
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\VU_2021.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2022.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 282
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\VU_2022.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\VU_2023.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\VU.parquet
# [INFO] Combined rows (ownership only): 310
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\VU_2023.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2007.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2007.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2008.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2008.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2009.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2009.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2010.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2010.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2011.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2011.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2012.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2012.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2013.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2013.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2014.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2014.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2015.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2015.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2016.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2016.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2017.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2017.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2018.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2018.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2019.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2019.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2020.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2020.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2021.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2021.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2022.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2022.csv.gz
# [INFO] Loading and joining data from:
#   - Ownership: ..\data_processed\ownership_history\guos\WF_2023.parquet
#   - Firmographics: ..\data_processed\firmographics_processed\firmographics_full\WF.parquet
# [INFO] Combined rows (ownership only): 0
# [MEMORY] Used: 15.8%, Available: 135.57 GB
# Saved at ..\zipped_files\guos_eu\WF_2023.csv.gz
